# %% [markdown]
# ### Prototype Code : Scraper

# %%
from selenium import webdriver

import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By

def print_list(group):
    for member in group:
        print(member)

# %%
# GET URL FUNCTION
def get_url():
    return input("Enter Website URL: ")

# DATA SCRAPING FUNCTION
def data_scrape(url):
    # Set up Selenium with a WebDriver, e.g., ChromeDriver
    driver = webdriver.Firefox()
    
    # Open the website
    driver.get(url)
    
    # Find all visible buttons
    buttons = driver.find_elements(By.CSS_SELECTOR, "button")
    visible_buttons = []
    for button in buttons:
        if button.is_displayed():
            store = f"Button Element: {button.text} with URL : {button.get_attribute('href')}"
            visible_buttons.append(store)
            
    # Find all visible links
    links = driver.find_elements(By.TAG_NAME,"a")
    visible_links = []
    for link in links:
        if link.is_displayed():
            store = f"Link Element: {link.text} with URL : {link.get_attribute('href')}"
            visible_links.append(store)
            
    # Find all visible forms (text inputs)
    visible_text_inputs = []
    # Scrape input fields
    input_fields = driver.find_elements(By.TAG_NAME,"input")
    for input_field in input_fields:
        if input_field.is_displayed():
            store = f"Input Field Name: {input_field.get_attribute("name")} Input field type: {input_field.get_attribute("type")}"
            visible_text_inputs.append(store)
    
    # Find all visible text
    visible_text = []
    # Scrape headings
    for level in range(1, 7):  # HTML has 6 levels of headings (h1 to h6)
        headings = driver.find_elements(By.TAG_NAME,f"h{level}")
        for heading in headings:
            if heading.is_displayed():
                store = f"Heading (h{level}): {heading.text}"
                visible_text.append(store)
    # Scrape text content
    paragraphs = driver.find_elements(By.TAG_NAME,"p")
    for paragraph in paragraphs:
        if paragraph.is_displayed():
            store = f"Paragraph Text: {paragraph.text}"
            visible_text.append(store)
            
    # Find all visible navigation menus
    visible_nav_menus = []
    # Scrape navigation menus
    navigation_menus = driver.find_elements(By.TAG_NAME,"nav")
    for nav in navigation_menus:
        if nav.is_displayed():
            store = f"Navigation Menu: {nav.text}"
            visible_nav_menus.append(store)
            
    # Close the browser
    driver.quit()

    # Return Data
    data = []
    
    # Data append
    data.append(visible_buttons)
    data.append(visible_links)
    data.append(visible_text_inputs)
    data.append(visible_text)
    data.append(visible_nav_menus)

    return data

# %%
# Possibly Outdated: Other methods
from selenium import webdriver

# Set up Selenium with a WebDriver, e.g., ChromeDriver
driver = webdriver.Chrome()

# Open the website
driver.get("https://example.com")

# Find an element (example button)
button = driver.find_element_by_css_selector("button")

# Get various properties
button_text = button.text
button_id = button.get_attribute("id")
button_class = button.get_attribute("class")
button_color = button.value_of_css_property("background-color")
button_size = button.size
button_location = button.location
button_tag_name = button.tag_name
button_visible = button.is_displayed()
button_enabled = button.is_enabled()
button_inner_html = button.get_attribute("innerHTML")

# Print properties
print("Button text:", button_text)
print("Button ID:", button_id)
print("Button class:", button_class)
print("Button color:", button_color)
print("Button size:", button_size)
print("Button location:", button_location)
print("Button tag name:", button_tag_name)
print("Button visible:", button_visible)
print("Button enabled:", button_enabled)
print("Button inner HTML:", button_inner_html)

# Close the browser
driver.quit()

# %% [markdown]
# ### Version 1: Improvement According to Design

# %% [markdown]
# ##### Planning

# %%
#####################################
# GET URL FUNCTION (non UI version) #
#####################################
def get_url():
    return input("Enter Website URL: ")

# DATA SCRAPING FUNCTION
def data_scrape(url):
    # Setup Selenium Webdriver
    # TODO : Add other drivers according to user settings. Detect user browser and use that as driver potentially
    driver = webdriver.Firefox()
    # Setup Return Data
    data = []

    # Open the website
    driver.get(url)

    #######################################
    ## GET UI ELEMENTS (must be visible) ##
    #######################################

    # BUTTONS
    # [~] TODO : "Button <button-name> with size <size> and color <color>. This button is <isEnabled>"
    """
    - Name (text)
    - Size 
    - Color 
    - isEnabled
    """
    buttons = driver.find_elements(By.CSS_SELECTOR, "button")
    visible_buttons = []
    for button in buttons:
        if button.is_displayed():
            
            # Variation a - Simple (only link assigned to button alongside button name)
            button_link = button.get_attribute('href')

            # Variation b - Complex (with additional properties)
            button_size = button.size
            button_color = button.value_of_css_property("background-color")
            button_enabled = "is clickable" if button.is_enabled() else "not clickable"
            button_template = f"with Size: {button_size} with Color: {button_color} and the button {button_enabled}"

            if (button_link != ""):
                store = f"Button Element: {button.text} with URL : {button_link} {button_template}"
            else:
                store = f"Button Element: {button.text} {button_template}"
            visible_buttons.append(store)
            
    # LINKS
    # [~] TODO : "Link <link-name> with url <href>"
    """
    - Name (text)
    - href
    """
    links = driver.find_elements(By.TAG_NAME,"a")
    visible_links = []
    for link in links:
        if link.is_displayed():
            
            link_url = f"with URL : {link.get_attribute('href')}" if link.get_attribute('href') != "" else ""

            store = f"Link Element: {link.text} {link_url}"
            visible_links.append(store)

    # VISIBLE TEXT
    # [~] TODO : 
    #   Separate Paragraphs From HNs [perhaps no need]
    #   ""<p> or <h> with content <text>""
    """
    - Content (text)
    """
    visible_text = []
    # HN
    for level in range(1, 7):  # HTML has 6 levels of headings (h1 to h6)
        headings = driver.find_elements(By.TAG_NAME,f"h{level}")
        for heading in headings:
            if heading.is_displayed():
                store = f"Heading Element (h{level}): {heading.text}"
                visible_text.append(store)
    # PARAGRAPHS
    paragraphs = driver.find_elements(By.TAG_NAME,"p")
    for paragraph in paragraphs:
        if paragraph.is_displayed():
            store = f"Paragraph Element: {paragraph.text}"
            visible_text.append(store)

    # FORMS : INPUT TYPE TEXT
    # [~] TODO : 
    #   Input Type Text : "form input of type text named <name>"
    #   Input Type Submit : "form input of type submit named <name>"
    """
    - input type text
        - Name
    - input type submit
        - Name
    """
    visible_text_inputs = []
    input_tags = driver.find_elements(By.TAG_NAME,"input")
    for input_tag in input_tags:
        if input_tag.is_displayed():
            if (input_tag.get_attribute("type") == "submit"):
                store = f"Form Submit Button Element: {input_tag.get_attribute("name")}"
            else:
                store = f"Input Field ELement: {input_tag.get_attribute("name")} and Input field type: {input_tag.get_attribute("type")}"
            visible_text_inputs.append(store)
            
    # Close the browser
    driver.quit()
    
    ###########################################
    ## COMPILE ELEMENTS INTO A LIST OF LISTS ##
    ###########################################

    data.append(visible_buttons)
    data.append(visible_links)
    data.append(visible_text_inputs)
    data.append(visible_text)

    return data

# %% [markdown]
# ##### Design-Coding : V1 (Individual) [TO-TEST]

# %%
driver = webdriver.Firefox()
driver.get("https://en.wikipedia.org/wiki/Philippines")

buttons = driver.find_elements(By.CSS_SELECTOR, "button")
visible_buttons = []
for button in buttons:
    if button.is_displayed():
        # Button Element Attributes
        button_text = f"Button Element '{button.text}'" if (button.text != None and button.text != "") else "Button Element Without Name"
        button_size = f"With Size Attribute {button.size}" if button.size != None else "Without Size Attribute"
        button_color = f"With Background Color {button.value_of_css_property("background-color")}" if button.value_of_css_property("background-color") != None else "Without Background Color"
        button_enabled = "and the button is Clickable" if button.is_enabled() else "and the button is not Clickable"
        
        # Store Button Element
        store = f"{button_text} {button_size} {button_color} {button_enabled}"
        visible_buttons.append(store)

driver.quit()

## BUTTON TEST ##
print_list(visible_buttons)
# Out:
# Button Element 'Search' With Size Attribute {'height': 32.0, 'width': 70.2833251953125} With Background Color rgb(248, 249, 250) and the button is Clickable
# Button Element 'hide' With Size Attribute {'height': 22.40000915527344, 'width': 36.80000305175781} With Background Color rgb(234, 236, 240) and the button is Clickable
# Button Element 'Toggle History subsection' With Size Attribute {'height': 22.0, 'width': 22.0} With Background Color rgba(0, 0, 0, 0) and the button is Clickable
# Button Element 'Toggle Geography subsection' With Size Attribute {'height': 22.0, 'width': 22.0} With Background Color rgba(0, 0, 0, 0) and the button is Clickable
# Button Element 'Toggle Government and politics subsection' With Size Attribute {'height': 22.0, 'width': 22.0} With Background Color rgba(0, 0, 0, 0) and the button is Clickable
# Button Element 'Toggle Economy subsection' With Size Attribute {'height': 22.0, 'width': 22.0} With Background Color rgba(0, 0, 0, 0) and the button is Clickable
# Button Element 'Toggle Infrastructure subsection' With Size Attribute {'height': 22.0, 'width': 22.0} With Background Color rgba(0, 0, 0, 0) and the button is Clickable
# Button Element 'Toggle Demographics subsection' With Size Attribute {'height': 22.0, 'width': 22.0} With Background Color rgba(0, 0, 0, 0) and the button is Clickable
# Button Element 'Toggle Culture subsection' With Size Attribute {'height': 22.0, 'width': 22.0} With Background Color rgba(0, 0, 0, 0) and the button is Clickable
# Button Element 'hide' With Size Attribute {'height': 22.40000915527344, 'width': 36.80000305175781} With Background Color rgb(234, 236, 240) and the button is Clickable

# %%
driver = webdriver.Firefox()
driver.get("https://en.wikipedia.org/wiki/Philippines")

links = driver.find_elements(By.TAG_NAME,"a")
visible_links = []
for link in links:
    if link.is_displayed():
        # Link Element Attributes
        link_text = f"Link Element '{link.text}'" if (link.text != None and link.text != "") else "Link Element Without Name"
        link_url = f"With URL {link.get_attribute('href')}" if link.get_attribute('href') != None else "Without URL"
        # Additional Attributes
        link_rel = f"With rel attribute {link.get_attribute('rel')}" if link.get_attribute('rel') != None and link.get_attribute('rel') != "" else ""
        link_target = f"With target attribute {link.get_attribute('target')}" if link.get_attribute('target') != None and link.get_attribute('target') != "" else ""
        link_download = f"This is a download link to document {link.get_attribute('download')}" if link.get_attribute('download') != None and link.get_attribute('download') != "" else ""
        
        # Store Link Element
        store = f"{link_text} {link_url} {link_rel} {link_target} {link_download}"
        visible_links.append(store)

driver.quit()

## LINKS TEST ##
print_list(visible_links)
# Out:
# Link Element 'Jump to content' With URL https://en.wikipedia.org/wiki/Philippines#bodyContent
# Link Element Without Name With URL https://en.wikipedia.org/wiki/Main_Page
# Link Element 'Donate' With URL https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=en
# Link Element 'Create account' With URL https://en.wikipedia.org/w/index.php?title=Special:CreateAccount&returnto=Philippines
# Link Element 'Log in' With URL https://en.wikipedia.org/w/index.php?title=Special:UserLogin&returnto=Philippines
# Link Element '(Top)' With URL https://en.wikipedia.org/wiki/Philippines#
# Link Element 'Etymology' With URL https://en.wikipedia.org/wiki/Philippines#Etymology
# Link Element 'History' With URL https://en.wikipedia.org/wiki/Philippines#History
# Link Element 'Geography' With URL https://en.wikipedia.org/wiki/Philippines#Geography
# Link Element 'Government and politics' With URL https://en.wikipedia.org/wiki/Philippines#Government_and_politics
# Link Element 'Economy' With URL https://en.wikipedia.org/wiki/Philippines#Economy
# Link Element 'Infrastructure' With URL https://en.wikipedia.org/wiki/Philippines#Infrastructure
# Link Element 'Demographics' With URL https://en.wikipedia.org/wiki/Philippines#Demographics
# Link Element 'Culture' With URL https://en.wikipedia.org/wiki/Philippines#Culture
# Link Element 'See also' With URL https://en.wikipedia.org/wiki/Philippines#See_also
# Link Element 'Notes' With URL https://en.wikipedia.org/wiki/Philippines#Notes
# Link Element 'References' With URL https://en.wikipedia.org/wiki/Philippines#References
# Link Element 'Further reading' With URL https://en.wikipedia.org/wiki/Philippines#Further_reading
# Link Element 'External links' With URL https://en.wikipedia.org/wiki/Philippines#External_links
# Link Element 'Article' With URL https://en.wikipedia.org/wiki/Philippines
# Link Element 'Talk' With URL https://en.wikipedia.org/wiki/Talk:Philippines With rel attribute discussion
# Link Element 'Read' With URL https://en.wikipedia.org/wiki/Philippines
# Link Element 'View source' With URL https://en.wikipedia.org/w/index.php?title=Philippines&action=edit
# Link Element 'View history' With URL https://en.wikipedia.org/w/index.php?title=Philippines&action=history
# Link Element 'Coordinates' With URL https://en.wikipedia.org/wiki/Geographic_coordinate_system
# Link Element '13°N 122°E' With URL https://geohack.toolforge.org/geohack.php?pagename=Philippines&params=13_N_122_E_type:country_region:PH
# Link Element Without Name With URL https://en.wikipedia.org/wiki/Wikipedia:Good_articles*
# Link Element Without Name With URL https://en.wikipedia.org/wiki/Wikipedia:Protection_policy#semi
# Link Element 'Philippine, Netherlands' With URL https://en.wikipedia.org/wiki/Philippine,_Netherlands
# Link Element 'too long' With URL https://en.wikipedia.org/wiki/Wikipedia:Article_size
# Link Element 'WP:SIZESPLIT' With URL https://en.wikipedia.org/wiki/Wikipedia:SIZESPLIT
# Link Element 'splitting' With URL https://en.wikipedia.org/wiki/Wikipedia:Splitting
# Link Element 'condensing' With URL https://en.wikipedia.org/wiki/Wikipedia:Summary_style
# Link Element 'subheadings' With URL https://en.wikipedia.org/wiki/Help:Section#Subsections
# Link Element 'talk page' With URL https://en.wikipedia.org/wiki/Talk:Philippines
# Link Element 'Filipino' With URL https://en.wikipedia.org/wiki/Filipino_language
# Link Element Without Name With URL https://en.wikipedia.org/wiki/File:Flag_of_the_Philippines.svg
# Link Element 'Flag' With URL https://en.wikipedia.org/wiki/Flag_of_the_Philippines
# Link Element Without Name With URL https://en.wikipedia.org/wiki/File:Coat_of_arms_of_the_Philippines.svg
# Link Element 'Coat of arms' With URL https://en.wikipedia.org/wiki/Coat_of_arms_of_the_Philippines
# Link Element '[a]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-1
# Link Element 'Maka-Diyos, Maka-tao, Makakalikasan at Makabansa' With URL https://en.wikipedia.org/wiki/Maka-Diyos,_Maka-tao,_Makakalikasan_at_Makabansa
# Link Element '[1]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-2
# Link Element 'Lupang Hinirang' With URL https://en.wikipedia.org/wiki/Lupang_Hinirang
# Link Element Without Name With URL https://en.wikipedia.org/wiki/File:PHL_orthographic.svg
# Link Element 'ASEAN' With URL https://en.wikipedia.org/wiki/ASEAN
# Link Element 'Legend' With URL https://en.wikipedia.org/wiki/File:Location_Philippines_ASEAN.svg
# Link Element 'Manila' With URL https://en.wikipedia.org/wiki/Manila
# Link Element 'Metro Manila' With URL https://en.wikipedia.org/wiki/Metro_Manila
# Link Element '[b]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-a-5
# Link Element 'Quezon City' With URL https://en.wikipedia.org/wiki/Quezon_City
# Link Element 'Filipino' With URL https://en.wikipedia.org/wiki/Filipino_language
# Link Element 'English' With URL https://en.wikipedia.org/wiki/Philippine_English
# Link Element '19 languages' With URL https://en.wikipedia.org/wiki/Languages_of_the_Philippines
# Link Element '[4]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-GMA-DepEd-7-Languages-6
# Link Element 'sign language' With URL https://en.wikipedia.org/wiki/Sign_language
# Link Element 'Filipino Sign Language' With URL https://en.wikipedia.org/wiki/Filipino_Sign_Language
# Link Element '[c]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-b-8
# Link Element 'Spanish' With URL https://en.wikipedia.org/wiki/Philippine_Spanish
# Link Element 'Arabic' With URL https://en.wikipedia.org/wiki/Arabic
# Link Element 'Ethnic groups' With URL https://en.wikipedia.org/wiki/Ethnic_group
# Link Element '[6]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-PSAGovPH-Ethnicity-2020Census-9
# Link Element 'Tagalog' With URL https://en.wikipedia.org/wiki/Tagalog_people
# Link Element 'Bisaya' With URL https://en.wikipedia.org/wiki/Visayans
# Link Element 'Ilocano' With URL https://en.wikipedia.org/wiki/Ilocano_people
# Link Element 'Cebuano' With URL https://en.wikipedia.org/wiki/Cebuano_people
# Link Element 'Ilonggo' With URL https://en.wikipedia.org/wiki/Hiligaynon_people
# Link Element 'Bicolano' With URL https://en.wikipedia.org/wiki/Bicolano_people
# Link Element 'other' With URL https://en.wikipedia.org/wiki/Ethnic_groups_in_the_Philippines
# Link Element '[7]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-PSAGovPH-Religion-2020Census-10
# Link Element 'Christianity' With URL https://en.wikipedia.org/wiki/Christianity_in_the_Philippines
# Link Element 'Catholicism' With URL https://en.wikipedia.org/wiki/Catholic_Church_in_the_Philippines
# Link Element '[d]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Catholic-2020Census-11
# Link Element 'Christian' With URL https://en.wikipedia.org/wiki/Religion_in_the_Philippines#Christianity
# Link Element 'Islam' With URL https://en.wikipedia.org/wiki/Islam_in_the_Philippines
# Link Element 'other' With URL https://en.wikipedia.org/wiki/Religion_in_the_Philippines#Other_religions
# Link Element 'none' With URL https://en.wikipedia.org/wiki/Irreligion_in_the_Philippines
# Link Element 'Demonym(s)' With URL https://en.wikipedia.org/wiki/Demonym
# Link Element 'Filipino' With URL https://en.wikipedia.org/wiki/Filipinos
# Link Element 'Pinoy' With URL https://en.wikipedia.org/wiki/Pinoy
# Link Element 'Government' With URL https://en.wikipedia.org/wiki/Politics_of_the_Philippines
# Link Element 'presidential republic' With URL https://en.wikipedia.org/wiki/Presidential_republic
# Link Element 'President' With URL https://en.wikipedia.org/wiki/President_of_the_Philippines
# Link Element 'Bongbong Marcos' With URL https://en.wikipedia.org/wiki/Bongbong_Marcos
# Link Element 'Vice President' With URL https://en.wikipedia.org/wiki/Vice_President_of_the_Philippines
# Link Element 'Sara Duterte' With URL https://en.wikipedia.org/wiki/Sara_Duterte
# Link Element 'Senate President' With URL https://en.wikipedia.org/wiki/President_of_the_Senate_of_the_Philippines
# Link Element 'Francis Escudero' With URL https://en.wikipedia.org/wiki/Francis_Escudero
# Link Element 'House Speaker' With URL https://en.wikipedia.org/wiki/Speaker_of_the_House_of_Representatives_of_the_Philippines
# Link Element 'Martin Romualdez' With URL https://en.wikipedia.org/wiki/Martin_Romualdez
# Link Element 'Chief Justice' With URL https://en.wikipedia.org/wiki/Chief_Justice_of_the_Philippines
# Link Element 'Alexander Gesmundo' With URL https://en.wikipedia.org/wiki/Alexander_Gesmundo
# Link Element 'Congress' With URL https://en.wikipedia.org/wiki/Congress_of_the_Philippines
# Link Element 'Upper house' With URL https://en.wikipedia.org/wiki/Upper_house
# Link Element 'Senate' With URL https://en.wikipedia.org/wiki/Senate_of_the_Philippines
# Link Element 'Lower house' With URL https://en.wikipedia.org/wiki/Lower_house
# Link Element 'House of Representatives' With URL https://en.wikipedia.org/wiki/House_of_Representatives_of_the_Philippines
# Link Element 'Independence' With URL https://en.wikipedia.org/wiki/Sovereignty_of_the_Philippines
# Link Element 'Spain' With URL https://en.wikipedia.org/wiki/Spain
# Link Element 'United States' With URL https://en.wikipedia.org/wiki/United_States
# Link Element 'Declaration' With URL https://en.wikipedia.org/wiki/Philippine_Declaration_of_Independence
# Link Element 'Cession' With URL https://en.wikipedia.org/wiki/Treaty_of_Paris_(1898)
# Link Element 'Self-government' With URL https://en.wikipedia.org/wiki/Commonwealth_of_the_Philippines
# Link Element 'Recognized' With URL https://en.wikipedia.org/wiki/Treaty_of_Manila_(1946)
# Link Element 'Constitution' With URL https://en.wikipedia.org/wiki/Constitution_of_the_Philippines
# Link Element 'Area' With URL https://en.wikipedia.org/wiki/Geography_of_the_Philippines
# Link Element '[8]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Philippines_country_profile-12
# Link Element '[9]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-13
# Link Element '[e]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-land-area-14
# Link Element '72nd' With URL https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_area
# Link Element '[10]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-CIAWorldFactBook-15
# Link Element 'Population' With URL https://en.wikipedia.org/wiki/Demographics_of_the_Philippines
# Link Element '[11]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-16
# Link Element '12th' With URL https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population
# Link Element '[12]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-PSAGovPH-2020Census-17
# Link Element '36th' With URL https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population_density
# Link Element 'GDP' With URL https://en.wikipedia.org/wiki/Gross_domestic_product
# Link Element 'PPP' With URL https://en.wikipedia.org/wiki/Purchasing_power_parity
# Link Element '[13]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-IMFWEO.PH-18
# Link Element '[13]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-IMFWEO.PH-18
# Link Element 'GDP' With URL https://en.wikipedia.org/wiki/Gross_domestic_product
# Link Element '[13]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-IMFWEO.PH-18
# Link Element '[13]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-IMFWEO.PH-18
# Link Element 'Gini' With URL https://en.wikipedia.org/wiki/Gini_coefficient
# Link Element '[14]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-19
# Link Element 'HDI' With URL https://en.wikipedia.org/wiki/Human_Development_Index
# Link Element '[15]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-UNHDR-20
# Link Element '113th' With URL https://en.wikipedia.org/wiki/List_of_countries_by_Human_Development_Index
# Link Element 'Philippine peso' With URL https://en.wikipedia.org/wiki/Philippine_peso
# Link Element '₱' With URL https://en.wikipedia.org/wiki/Philippine_peso_sign
# Link Element 'PHP' With URL https://en.wikipedia.org/wiki/ISO_4217
# Link Element 'UTC' With URL https://en.wikipedia.org/wiki/Coordinated_Universal_Time
# Link Element 'PhST' With URL https://en.wikipedia.org/wiki/Philippine_Standard_Time
# Link Element 'Calling code' With URL https://en.wikipedia.org/wiki/Telephone_numbers_in_the_Philippines
# Link Element '+63' With URL https://en.wikipedia.org/wiki/Telephone_numbers_in_the_Philippines
# Link Element 'ISO 3166 code' With URL https://en.wikipedia.org/wiki/ISO_3166
# Link Element 'PH' With URL https://en.wikipedia.org/wiki/ISO_3166-2:PH
# Link Element 'Internet TLD' With URL https://en.wikipedia.org/wiki/Country_code_top-level_domain
# Link Element '.ph' With URL https://en.wikipedia.org/wiki/.ph
# Link Element '[f]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-21
# Link Element '[g]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-22
# Link Element 'archipelagic country' With URL https://en.wikipedia.org/wiki/Archipelagic_state
# Link Element 'Southeast Asia' With URL https://en.wikipedia.org/wiki/Southeast_Asia
# Link Element 'Pacific Ocean' With URL https://en.wikipedia.org/wiki/Pacific_Ocean
# Link Element '7,641 islands' With URL https://en.wikipedia.org/wiki/List_of_islands_of_the_Philippines
# Link Element 'three main geographical divisions' With URL https://en.wikipedia.org/wiki/Island_groups_of_the_Philippines
# Link Element 'Luzon' With URL https://en.wikipedia.org/wiki/Luzon
# Link Element 'Visayas' With URL https://en.wikipedia.org/wiki/Visayas
# Link Element 'Mindanao' With URL https://en.wikipedia.org/wiki/Mindanao
# Link Element 'South China Sea' With URL https://en.wikipedia.org/wiki/South_China_Sea
# Link Element 'Philippine Sea' With URL https://en.wikipedia.org/wiki/Philippine_Sea
# Link Element 'Celebes Sea' With URL https://en.wikipedia.org/wiki/Celebes_Sea
# Link Element 'maritime borders' With URL https://en.wikipedia.org/wiki/Maritime_border
# Link Element 'Taiwan' With URL https://en.wikipedia.org/wiki/Taiwan
# Link Element 'Japan' With URL https://en.wikipedia.org/wiki/Japan
# Link Element 'Palau' With URL https://en.wikipedia.org/wiki/Palau
# Link Element 'Indonesia' With URL https://en.wikipedia.org/wiki/Indonesia
# Link Element 'Malaysia' With URL https://en.wikipedia.org/wiki/Malaysia
# Link Element 'Vietnam' With URL https://en.wikipedia.org/wiki/Vietnam
# Link Element 'China' With URL https://en.wikipedia.org/wiki/China
# Link Element 'twelfth-most-populous country' With URL https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population
# Link Element 'ethnicities' With URL https://en.wikipedia.org/wiki/Ethnic_groups_in_the_Philippines
# Link Element 'cultures' With URL https://en.wikipedia.org/wiki/Culture_of_the_Philippines
# Link Element 'Manila' With URL https://en.wikipedia.org/wiki/Manila
# Link Element 'the country's capital' With URL https://en.wikipedia.org/wiki/Capital_of_the_Philippines
# Link Element 'its most populated city' With URL https://en.wikipedia.org/wiki/Cities_of_the_Philippines#Largest_cities
# Link Element 'Quezon City' With URL https://en.wikipedia.org/wiki/Quezon_City
# Link Element 'Metro Manila' With URL https://en.wikipedia.org/wiki/Metro_Manila
# Link Element 'Negritos' With URL https://en.wikipedia.org/wiki/Negrito
# Link Element 'waves' With URL https://en.wikipedia.org/wiki/Models_of_migration_to_the_Philippines
# Link Element 'Austronesian peoples' With URL https://en.wikipedia.org/wiki/Austronesian_peoples
# Link Element 'animism' With URL https://en.wikipedia.org/wiki/Animism
# Link Element 'Hinduism' With URL https://en.wikipedia.org/wiki/Hinduism
# Link Element 'Buddhist' With URL https://en.wikipedia.org/wiki/Buddhist
# Link Element 'Islam' With URL https://en.wikipedia.org/wiki/Islam
# Link Element 'island-kingdoms' With URL https://en.wikipedia.org/wiki/History_of_the_Philippines_(900%E2%80%931565)
# Link Element 'Tang' With URL https://en.wikipedia.org/wiki/Tang_dynasty
# Link Element 'Song' With URL https://en.wikipedia.org/wiki/Southern_Song
# Link Element 'Chinese' With URL https://en.wikipedia.org/wiki/Sangley
# Link Element 'intermix' With URL https://en.wikipedia.org/wiki/Interethnic_marriage
# Link Element 'Ferdinand Magellan' With URL https://en.wikipedia.org/wiki/Ferdinand_Magellan
# Link Element 'Spanish colonization' With URL https://en.wikipedia.org/wiki/Spanish_Colonization_in_the_Philippines
# Link Element 'Ruy López de Villalobos' With URL https://en.wikipedia.org/wiki/Ruy_L%C3%B3pez_de_Villalobos
# Link Element 'King Philip II of Castile' With URL https://en.wikipedia.org/wiki/King_Philip_II_of_Castile
# Link Element 'Catholicism' With URL https://en.wikipedia.org/wiki/Catholic_Church
# Link Element 'trans-Pacific trade' With URL https://en.wikipedia.org/wiki/Spanish_treasure_fleet
# Link Element 'Hispanic' With URL https://en.wikipedia.org/wiki/Spaniard
# Link Element 'Latin America' With URL https://en.wikipedia.org/wiki/Latin_American_Asian
# Link Element 'Iberia' With URL https://en.wikipedia.org/wiki/Iberia
# Link Element 'Philippine Revolution' With URL https://en.wikipedia.org/wiki/Philippine_Revolution
# Link Element 'Spanish–American War' With URL https://en.wikipedia.org/wiki/Spanish%E2%80%93American_War
# Link Element 'Filipino revolutionaries' With URL https://en.wikipedia.org/wiki/Hong_Kong_Junta
# Link Element 'First Philippine Republic' With URL https://en.wikipedia.org/wiki/First_Philippine_Republic
# Link Element 'Philippine–American War' With URL https://en.wikipedia.org/wiki/Philippine%E2%80%93American_War
# Link Element 'Japanese invasion' With URL https://en.wikipedia.org/wiki/Philippines_campaign_(1941%E2%80%931942)
# Link Element 'World War II' With URL https://en.wikipedia.org/wiki/World_War_II
# Link Element 'the United States retook the Philippines from the Japanese' With URL https://en.wikipedia.org/wiki/Philippines_campaign_(1944%E2%80%931945)
# Link Element 'a decades-long dictatorship' With URL https://en.wikipedia.org/wiki/Martial_law_under_Ferdinand_Marcos
# Link Element 'a nonviolent revolution' With URL https://en.wikipedia.org/wiki/People_Power_Revolution
# Link Element 'emerging market' With URL https://en.wikipedia.org/wiki/Emerging_market
# Link Element 'developing' With URL https://en.wikipedia.org/wiki/Developing_country
# Link Element 'newly industrialized country' With URL https://en.wikipedia.org/wiki/Newly_industrialized_country
# Link Element 'United Nations' With URL https://en.wikipedia.org/wiki/United_Nations
# Link Element 'World Trade Organization' With URL https://en.wikipedia.org/wiki/World_Trade_Organization
# Link Element 'ASEAN' With URL https://en.wikipedia.org/wiki/ASEAN
# Link Element 'Asia-Pacific Economic Cooperation' With URL https://en.wikipedia.org/wiki/Asia-Pacific_Economic_Cooperation
# Link Element 'East Asia Summit' With URL https://en.wikipedia.org/wiki/East_Asia_Summit
# Link Element 'Non-Aligned Movement' With URL https://en.wikipedia.org/wiki/Non-Aligned_Movement
# Link Element 'major non-NATO ally' With URL https://en.wikipedia.org/wiki/Major_non-NATO_ally
# Link Element 'Ring of Fire' With URL https://en.wikipedia.org/wiki/Ring_of_Fire
# Link Element 'earthquakes' With URL https://en.wikipedia.org/wiki/List_of_earthquakes_in_the_Philippines
# Link Element 'typhoons' With URL https://en.wikipedia.org/wiki/Typhoons_in_the_Philippines
# Link Element 'level of biodiversity' With URL https://en.wikipedia.org/wiki/Megadiverse_countries
# Link Element 'Names of the Philippines' With URL https://en.wikipedia.org/wiki/Names_of_the_Philippines
# Link Element 'Ruy López de Villalobos' With URL https://en.wikipedia.org/wiki/Ruy_L%C3%B3pez_de_Villalobos
# Link Element 'Leyte' With URL https://en.wikipedia.org/wiki/Leyte
# Link Element 'Samar' With URL https://en.wikipedia.org/wiki/Samar
# Link Element 'Prince of Asturias' With URL https://en.wikipedia.org/wiki/Prince_of_Asturias
# Link Element 'Philip II of Castile' With URL https://en.wikipedia.org/wiki/Philip_II_of_Castile
# Link Element '[16]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Scott-1994-23
# Link Element '6' With URL https://books.google.com/books?id=15KZU-yMuisC&pg=PA6 With rel attribute nofollow
# Link Element '[17]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-24
# Link Element '[18]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-25
# Link Element '[19]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-26
# Link Element 'Philippine Revolution' With URL https://en.wikipedia.org/wiki/Philippine_Revolution
# Link Element 'Malolos Congress' With URL https://en.wikipedia.org/wiki/Malolos_Congress
# Link Element 'Philippine Republic' With URL https://en.wikipedia.org/wiki/First_Philippine_Republic
# Link Element '[20]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-27
# Link Element '[21]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-28
# Link Element 'United States' With URL https://en.wikipedia.org/wiki/United_States
# Link Element 'Jones Law' With URL https://en.wikipedia.org/wiki/Jones_Law_(Philippines)
# Link Element '[22]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-29
# Link Element '[23]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-30
# Link Element '[24]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-31
# Link Element '[25]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-32
# Link Element 'History of the Philippines' With URL https://en.wikipedia.org/wiki/History_of_the_Philippines
# Link Element 'Timeline of Philippine history' With URL https://en.wikipedia.org/wiki/Timeline_of_Philippine_history
# Link Element 'Prehistory of the Philippines' With URL https://en.wikipedia.org/wiki/Prehistory_of_the_Philippines
# Link Element Without Name With URL https://en.wikipedia.org/wiki/File:Manunggul_Jar.jpg
# Link Element 'Manunggul burial jar' With URL https://en.wikipedia.org/wiki/Manunggul_Jar
# Link Element 'burial jars' With URL https://en.wikipedia.org/wiki/Burial_jar
# Link Element 'evidence' With URL https://en.wikipedia.org/wiki/Archaeology_of_the_Philippines
# Link Element 'hominins' With URL https://en.wikipedia.org/wiki/Hominins
# Link Element '[26]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-33
# Link Element 'Callao Cave' With URL https://en.wikipedia.org/wiki/Callao_Cave
# Link Element 'Homo luzonensis' With URL https://en.wikipedia.org/wiki/Homo_luzonensis
# Link Element '[27]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-34
# Link Element '[28]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-35
# Link Element 'modern human' With URL https://en.wikipedia.org/wiki/Modern_human
# Link Element 'Tabon Caves' With URL https://en.wikipedia.org/wiki/Tabon_Caves
# Link Element 'Palawan' With URL https://en.wikipedia.org/wiki/Palawan
# Link Element 'U/Th-dated' With URL https://en.wikipedia.org/wiki/U/Th-dated
# Link Element '[29]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-36
# Link Element 'Tabon Man' With URL https://en.wikipedia.org/wiki/Tabon_Man
# Link Element 'Negrito' With URL https://en.wikipedia.org/wiki/Negrito
# Link Element 'southern Asia' With URL https://en.wikipedia.org/wiki/South_Asia
# Link Element 'Sundaland' With URL https://en.wikipedia.org/wiki/Sundaland
# Link Element 'Sahul' With URL https://en.wikipedia.org/wiki/Sahul
# Link Element '[30]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-37
# Link Element 'Batanes' With URL https://en.wikipedia.org/wiki/Batanes
# Link Element 'ijangs' With URL https://en.wikipedia.org/wiki/Ijang
# Link Element '[31]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-38
# Link Element 'Luzon' With URL https://en.wikipedia.org/wiki/Luzon
# Link Element 'Jade artifacts' With URL https://en.wikipedia.org/w/index.php?title=Philippine_jade_culture&action=edit&redlink=1
# Link Element '[32]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-39
# Link Element '[33]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-40
# Link Element 'lingling-o' With URL https://en.wikipedia.org/wiki/Lingling-o
# Link Element '[34]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-41
# Link Element 'hunter-gatherer' With URL https://en.wikipedia.org/wiki/Hunter-gatherer
# Link Element 'plutocracies' With URL https://en.wikipedia.org/wiki/Plutocracies
# Link Element '[35]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Legarda-2001-42
# Link Element 'History of the Philippines (900–1565)' With URL https://en.wikipedia.org/wiki/History_of_the_Philippines_(900%E2%80%931565)
# Link Element Without Name With URL https://en.wikipedia.org/wiki/File:Naturales_4.png
# Link Element 'Laguna Copperplate Inscription' With URL https://en.wikipedia.org/wiki/Laguna_Copperplate_Inscription
# Link Element 'Old Malay' With URL https://en.wikipedia.org/wiki/Old_Malay
# Link Element 'Kawi' With URL https://en.wikipedia.org/wiki/Kawi_alphabet
# Link Element '[36]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-43
# Link Element 'societal changes' With URL https://en.wikipedia.org/wiki/Cultural_achievements_of_pre-colonial_Philippines
# Link Element '[37]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-deGraaf-1977-44
# Link Element 'polities' With URL https://en.wikipedia.org/wiki/Polities
# Link Element '[38]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Junker-1999-45
# Link Element '[39]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-46
# Link Element 'Tang dynasty' With URL https://en.wikipedia.org/wiki/Tang_dynasty
# Link Element '[40]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-47
# Link Element '[41]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-:0-48
# Link Element 'Song dynasty' With URL https://en.wikipedia.org/wiki/Song_dynasty
# Link Element '[42]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-49
# Link Element '[43]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-50
# Link Element '[41]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-:0-48
# Link Element 'tributary system of China' With URL https://en.wikipedia.org/wiki/Tributary_system_of_China
# Link Element '[16]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Scott-1994-23
# Link Element '[38]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Junker-1999-45
# Link Element 'Southern' With URL https://en.wikipedia.org/wiki/Northern_and_southern_China
# Link Element 'Chinese' With URL https://en.wikipedia.org/wiki/Han_Chinese
# Link Element 'Southern Fujian' With URL https://en.wikipedia.org/wiki/Southern_Fujian
# Link Element '[44]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-51
# Link Element '[45]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-52
# Link Element '[46]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-53
# Link Element 'began to spread' With URL https://en.wikipedia.org/wiki/Indian_influences_in_early_Philippine_polities
# Link Element 'Majapahit Empire' With URL https://en.wikipedia.org/wiki/Majapahit
# Link Element '[47]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-54
# Link Element '[48]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-55
# Link Element 'Sulu Archipelago' With URL https://en.wikipedia.org/wiki/Sulu_Archipelago
# Link Element '[37]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-deGraaf-1977-44
# Link Element 'Maynila' With URL https://en.wikipedia.org/wiki/Maynila_(historical_polity)
# Link Element '[49]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Ring-1996-56
# Link Element 'Tondo' With URL https://en.wikipedia.org/wiki/Tondo_(historical_polity)
# Link Element 'Namayan' With URL https://en.wikipedia.org/wiki/Namayan
# Link Element 'Pangasinan' With URL https://en.wikipedia.org/wiki/Caboloan
# Link Element 'Caboloan' With URL https://en.wikipedia.org/wiki/Caboloan
# Link Element 'Cebu' With URL https://en.wikipedia.org/wiki/Cebu_(historical_state)
# Link Element 'Butuan' With URL https://en.wikipedia.org/wiki/Butuan_(historical_polity)
# Link Element 'Maguindanao' With URL https://en.wikipedia.org/wiki/Sultanate_of_Maguindanao
# Link Element 'Lanao' With URL https://en.wikipedia.org/wiki/Confederate_States_of_Lanao
# Link Element 'Sulu' With URL https://en.wikipedia.org/wiki/Sultanate_of_Sulu
# Link Element 'Ma-i' With URL https://en.wikipedia.org/wiki/Ma-i
# Link Element '[50]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-57
# Link Element '[38]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Junker-1999-45
# Link Element '[51]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Wernstedt-1967-58
# Link Element '672' With URL https://books.google.com/books?id=6Pn0Pfh1Cl0C&pg=PA672 With rel attribute nofollow
# Link Element 'datus' With URL https://en.wikipedia.org/wiki/Datu
# Link Element 'barangays' With URL https://en.wikipedia.org/wiki/Barangay_state
# Link Element '[52]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-59
# Link Element '[38]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Junker-1999-45
# Link Element '[53]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-60
# Link Element 'paramount datu' With URL https://en.wikipedia.org/wiki/Paramount_rulers_in_early_Philippine_history
# Link Element '[54]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Newson-61
# Link Element '58' With URL https://books.google.com/books?id=A40BEAAAQBAJ&pg=PA58 With rel attribute nofollow
# Link Element '[35]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Legarda-2001-42
# Link Element 'rajah' With URL https://en.wikipedia.org/wiki/Rajah
# Link Element 'sultan' With URL https://en.wikipedia.org/wiki/Sultan
# Link Element '[55]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-62
# Link Element '[56]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-63
# Link Element '[54]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Newson-61
# Link Element '18' With URL https://books.google.com/books?id=A40BEAAAQBAJ&pg=PA18 With rel attribute nofollow
# Link Element 'frequency of typhoons' With URL https://en.wikipedia.org/wiki/Typhoon#Frequency
# Link Element 'Ring of Fire' With URL https://en.wikipedia.org/wiki/Ring_of_Fire
# Link Element '[57]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-64
# Link Element 'Ferdinand Magellan' With URL https://en.wikipedia.org/wiki/Ferdinand_Magellan
# Link Element 'Lapulapu' With URL https://en.wikipedia.org/wiki/Lapulapu
# Link Element 'Battle of Mactan' With URL https://en.wikipedia.org/wiki/Battle_of_Mactan
# Link Element '[58]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Woods-2006-65
# Link Element '21' With URL https://books.google.com/books?id=2Z-n_kDTxf0C&pg=PT46 With rel attribute nofollow
# Link Element '[59]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Guillermo-2012-66
# Link Element '261' With URL https://books.google.com/books?id=wmgX9M_yETIC&pg=PA261 With rel attribute nofollow
# Link Element 'History of the Philippines (1565–1898)' With URL https://en.wikipedia.org/wiki/History_of_the_Philippines_(1565%E2%80%931898)
# Link Element 'History of the Philippines (1898–1946)' With URL https://en.wikipedia.org/wiki/History_of_the_Philippines_(1898%E2%80%931946)
# Link Element Without Name With URL https://en.wikipedia.org/wiki/File:Vista_del_Puente_de_Manila_(1847).png
# Link Element 'Manila' With URL https://en.wikipedia.org/wiki/Manila
# Link Element 'Crown of Castile' With URL https://en.wikipedia.org/wiki/Crown_of_Castile
# Link Element 'Miguel López de Legazpi' With URL https://en.wikipedia.org/wiki/Miguel_L%C3%B3pez_de_Legazpi
# Link Element 'New Spain' With URL https://en.wikipedia.org/wiki/New_Spain
# Link Element '[60]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-67
# Link Element '[61]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-68
# Link Element '[62]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-deBorja-2005-69
# Link Element 'Filipinos' With URL https://en.wikipedia.org/wiki/Filipinos
# Link Element 'as slaves' With URL https://en.wikipedia.org/wiki/History_of_Spanish_slavery_in_the_Philippines
# Link Element '[63]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-70
# Link Element 'Latin Americans' With URL https://en.wikipedia.org/wiki/Latin_American_Asian
# Link Element '[64]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-71
# Link Element 'Spanish Manila' With URL https://en.wikipedia.org/wiki/Intramuros
# Link Element 'Captaincy General of the Philippines' With URL https://en.wikipedia.org/wiki/Captaincy_General_of_the_Philippines
# Link Element 'Spanish East Indies' With URL https://en.wikipedia.org/wiki/Spanish_East_Indies
# Link Element '[65]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-72
# Link Element '[66]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-73
# Link Element '[67]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-74
# Link Element 'divide and conquer' With URL https://en.wikipedia.org/wiki/Divide_and_rule
# Link Element '[59]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Guillermo-2012-66
# Link Element '374' With URL https://books.google.com/books?id=wmgX9M_yETIC&pg=PA374 With rel attribute nofollow
# Link Element '[68]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-75
# Link Element '[69]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-76
# Link Element 'consolidated into towns' With URL https://en.wikipedia.org/wiki/Reductions
# Link Element 'Catholic missionaries' With URL https://en.wikipedia.org/wiki/Friars_in_Spanish_Philippines
# Link Element 'Christianity' With URL https://en.wikipedia.org/wiki/Christianity
# Link Element '[70]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Abinales-2005-77
# Link Element '53' With URL https://books.google.com/books?id=xiOQdEzgP9kC&pg=PA53 With rel attribute nofollow
# Link Element '68' With URL https://books.google.com/books?id=xiOQdEzgP9kC&pg=PA68 With rel attribute nofollow
# Link Element '[71]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-78
# Link Element 'Syncretist' With URL https://en.wikipedia.org/wiki/Religious_Syncretism
# Link Element '[72]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-79
# Link Element 'Christianization' With URL https://en.wikipedia.org/wiki/Christianization
# Link Element 'Spanish friars' With URL https://en.wikipedia.org/wiki/Friars_in_Spanish_Philippines
# Link Element 'Mexico City' With URL https://en.wikipedia.org/wiki/Mexico_City
# Link Element 'Madrid' With URL https://en.wikipedia.org/wiki/Madrid
# Link Element 'Mexican War of Independence' With URL https://en.wikipedia.org/wiki/Mexican_War_of_Independence
# Link Element '[73]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Halili-2004-80
# Link Element '81' With URL https://books.google.com/books?id=gUt5v8ET4QYC&pg=PA81 With rel attribute nofollow
# Link Element 'trans-Pacific trade' With URL https://en.wikipedia.org/wiki/Spanish_treasure_fleet
# Link Element '[74]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-81
# Link Element 'Manila galleons' With URL https://en.wikipedia.org/wiki/Manila_galleon
# Link Element 'Bicol' With URL https://en.wikipedia.org/wiki/Bicol_Region
# Link Element 'Cavite' With URL https://en.wikipedia.org/wiki/Cavite
# Link Element '[75]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-82
# Link Element '[76]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-83
# Link Element 'indigenous revolts' With URL https://en.wikipedia.org/wiki/Philippine_revolts_against_Spain
# Link Element '[73]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Halili-2004-80
# Link Element '111–122' With URL https://books.google.com/books?id=gUt5v8ET4QYC&pg=PA111 With rel attribute nofollow
# Link Element '[77]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Ooi-2004-84
# Link Element '1077' With URL https://books.google.com/books?id=QKgraWbb7yoC&pg=PA1077 With rel attribute nofollow
# Link Element '[78]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-85
# Link Element 'Moro piracy' With URL https://en.wikipedia.org/wiki/Piracy_in_the_Sulu_and_Celebes_Seas
# Link Element '[79]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-86
# Link Element 'war against the Dutch' With URL https://en.wikipedia.org/wiki/Battles_of_La_Naval_de_Manila
# Link Element 'British occupation of Manila' With URL https://en.wikipedia.org/wiki/British_occupation_of_Manila
# Link Element '[80]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Dolan-1991-87
# Link Element '4' With URL https://web.archive.org/web/20060927161256/http://countrystudies.us/philippines/4.htm With rel attribute nofollow
# Link Element 'undue weight?' With URL https://en.wikipedia.org/wiki/Wikipedia:Neutral_point_of_view#Due_and_undue_weight
# Link Element 'discuss' With URL https://en.wikipedia.org/wiki/Talk:Philippines#undue
# Link Element '[77]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Ooi-2004-84
# Link Element '1077' With URL https://books.google.com/books?id=QKgraWbb7yoC&pg=PA1077 With rel attribute nofollow
# Link Element '[54]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Newson-61
# Link Element '7–8' With URL https://books.google.com/books?id=A40BEAAAQBAJ&pg=PA7 With rel attribute nofollow
# Link Element '[81]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-88
# Link Element '[77]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Ooi-2004-84
# Link Element '1077' With URL https://books.google.com/books?id=QKgraWbb7yoC&pg=PA1077 With rel attribute nofollow
# Link Element '[54]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Newson-61
# Link Element '8' With URL https://books.google.com/books?id=A40BEAAAQBAJ&pg=PA8 With rel attribute nofollow
# Link Element '[82]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-89
# Link Element 'British forces occupied Manila' With URL https://en.wikipedia.org/wiki/British_occupation_of_Manila
# Link Element 'Seven Years' War' With URL https://en.wikipedia.org/wiki/Seven_Years%27_War
# Link Element '1763 Treaty of Paris' With URL https://en.wikipedia.org/wiki/Treaty_of_Paris_(1763)
# Link Element '[62]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-deBorja-2005-69
# Link Element 'Reconquista' With URL https://en.wikipedia.org/wiki/Reconquista
# Link Element '[83]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-90
# Link Element '[84]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-91
# Link Element 'Spanish–Moro conflict' With URL https://en.wikipedia.org/wiki/Spanish%E2%80%93Moro_conflict
# Link Element 'Mindanao' With URL https://en.wikipedia.org/wiki/Mindanao
# Link Element 'Jolo' With URL https://en.wikipedia.org/wiki/Jolo
# Link Element '[85]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-92
# Link Element 'Moro' With URL https://en.wikipedia.org/wiki/Moro_people
# Link Element 'Sultanate of Sulu' With URL https://en.wikipedia.org/wiki/Sultanate_of_Sulu
# Link Element '[86]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-93
# Link Element '[87]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-94
# Link Element Without Name With URL https://en.wikipedia.org/wiki/File:Ilustrados_1890.jpg
# Link Element 'Ilustrados' With URL https://en.wikipedia.org/wiki/Ilustrado
# Link Element 'Madrid' With URL https://en.wikipedia.org/wiki/Madrid
# Link Element '[88]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-95
# Link Element '[89]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-96
# Link Element 'Spaniards born in the Philippines' With URL https://en.wikipedia.org/wiki/Spanish_Filipino
# Link Element '[90]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-97
# Link Element '[91]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-98
# Link Element 'colonial troops' With URL https://en.wikipedia.org/wiki/Colonial_troops
# Link Element 'three activist Catholic priests' With URL https://en.wikipedia.org/wiki/Gomburza
# Link Element 'questionable grounds' With URL https://en.wikipedia.org/wiki/1872_Cavite_mutiny
# Link Element '[92]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-99
# Link Element '[93]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-100
# Link Element 'Propaganda Movement' With URL https://en.wikipedia.org/wiki/Propaganda_Movement
# Link Element 'Marcelo H. del Pilar' With URL https://en.wikipedia.org/wiki/Marcelo_H._del_Pilar
# Link Element 'José Rizal' With URL https://en.wikipedia.org/wiki/Jos%C3%A9_Rizal
# Link Element 'Graciano López Jaena' With URL https://en.wikipedia.org/wiki/Graciano_L%C3%B3pez_Jaena
# Link Element 'Mariano Ponce' With URL https://en.wikipedia.org/wiki/Mariano_Ponce
# Link Element '[94]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-101
# Link Element '[95]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-102
# Link Element 'Andrés Bonifacio' With URL https://en.wikipedia.org/wiki/Andr%C3%A9s_Bonifacio
# Link Element 'Katipunan' With URL https://en.wikipedia.org/wiki/Katipunan
# Link Element '[73]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Halili-2004-80
# Link Element '137' With URL https://books.google.com/books?id=gUt5v8ET4QYC&pg=PA137 With rel attribute nofollow
# Link Element 'Cry of Pugad Lawin' With URL https://en.wikipedia.org/wiki/Cry_of_Pugad_Lawin
# Link Element 'Philippine Revolution' With URL https://en.wikipedia.org/wiki/Philippine_Revolution
# Link Element '[96]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-103
# Link Element 'Tejeros Convention' With URL https://en.wikipedia.org/wiki/Tejeros_Convention
# Link Element 'Emilio Aguinaldo' With URL https://en.wikipedia.org/wiki/Emilio_Aguinaldo
# Link Element '[97]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Duka-2008-104
# Link Element '145–147' With URL https://books.google.com/books?id=4wk8yqCEmJUC&pg=PA147 With rel attribute nofollow
# Link Element 'Pact of Biak-na-Bato' With URL https://en.wikipedia.org/wiki/Pact_of_Biak-na-Bato
# Link Element 'Hong Kong Junta' With URL https://en.wikipedia.org/wiki/Hong_Kong_Junta
# Link Element 'Spanish–American War' With URL https://en.wikipedia.org/wiki/Spanish%E2%80%93American_War
# Link Element 'declared independence' With URL https://en.wikipedia.org/wiki/Philippine_Declaration_of_Independence
# Link Element '[98]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Abinales-2022-105
# Link Element '26' With URL https://books.google.com/books?id=0Hd3EAAAQBAJ&pg=PA26 With rel attribute nofollow
# Link Element 'ceded by Spain' With URL https://en.wikipedia.org/wiki/Treaty_of_Paris_(1898)
# Link Element 'Puerto Rico' With URL https://en.wikipedia.org/wiki/Puerto_Rico
# Link Element 'Guam' With URL https://en.wikipedia.org/wiki/Guam
# Link Element '[99]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-106
# Link Element '[100]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-107
# Link Element 'First Philippine Republic' With URL https://en.wikipedia.org/wiki/First_Philippine_Republic
# Link Element '[101]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-108
# Link Element 'outbreak of hostilities' With URL https://en.wikipedia.org/wiki/Battle_of_Manila_(1899)
# Link Element '[h]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-109
# Link Element 'Philippine–American War' With URL https://en.wikipedia.org/wiki/Philippine%E2%80%93American_War
# Link Element '[102]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Nation18990504-110
# Link Element '[103]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-111
# Link Element '[104]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-112
# Link Element '[105]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-113
# Link Element Without Name With URL https://en.wikipedia.org/wiki/File:General_Gregorio_del_Pilar_and_troops_in_Pampanga_c1898.jpg
# Link Element 'Gregorio del Pilar' With URL https://en.wikipedia.org/wiki/Gregorio_del_Pilar
# Link Element 'Philippine-American War' With URL https://en.wikipedia.org/wiki/Philippine-American_War
# Link Element '[106]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Tucker-2009-114
# Link Element 'concentration camps' With URL https://en.wikipedia.org/wiki/List_of_concentration_and_internment_camps#Philippines
# Link Element '[107]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-115
# Link Element '[108]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-116
# Link Element 'American civilian government' With URL https://en.wikipedia.org/wiki/Insular_Government_of_the_Philippine_Islands
# Link Element 'Philippine Organic Act' With URL https://en.wikipedia.org/wiki/Philippine_Organic_Act_(1902)
# Link Element '[109]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-117
# Link Element 'extension of the Philippine Republic' With URL https://en.wikipedia.org/wiki/Tagalog_Republic#Sakay
# Link Element '[97]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Duka-2008-104
# Link Element '200–202' With URL https://books.google.com/books?id=4wk8yqCEmJUC&pg=PA200 With rel attribute nofollow
# Link Element '[106]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Tucker-2009-114
# Link Element 'securing the Sultanate of Sulu' With URL https://en.wikipedia.org/wiki/Kiram%E2%80%93Bates_Treaty
# Link Element '[110]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-118
# Link Element '[111]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-119
# Link Element '[112]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-120
# Link Element '[113]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-121
# Link Element '[114]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-122
# Link Element '[115]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Armes-1987-123
# Link Element '[116]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Tofighian-2006-124
# Link Element 'Tagalog' With URL https://en.wikipedia.org/wiki/Tagalog_language
# Link Element '[70]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Abinales-2005-77
# Link Element '121' With URL https://books.google.com/books?id=xiOQdEzgP9kC&pg=PA121 With rel attribute nofollow
# Link Element 'Taft Commission' With URL https://en.wikipedia.org/wiki/Taft_Commission
# Link Element '[77]' With URL https://en.wikipedia.org/wiki/Philippines#cite_note-Ooi-2004-84
# ...
# Link Element '978-1-4629-0533-1' With URL https://en.wikipedia.org/wiki/Special:BookSources/978-1-4629-0533-1
# Link Element '^' With URL https://en.wikipedia.org/wiki/Philippines#cite_ref-701
# Link Element 'Modern Sports in Asia: Cultural Perspectives' With URL https://books.google.com/books?id=DYz7CwAAQBAJ With rel attribute nofollow
# Link Element 'Routledge' With URL https://en.wikipedia.org/wiki/Routledge
# Link Element '87' With URL https://books.google.com/books?id=DYz7CwAAQBAJ&pg=PA87 With rel attribute nofollow
# Link Element 'ISBN' With URL https://en.wikipedia.org/wiki/ISBN_(identifier)
# Link Element '978-1-317-58638-8' With URL https://en.wikipedia.org/wiki/Special:BookSources/978-1-317-58638-8
# Link Element '^' With URL https://en.wikipedia.org/wiki/Philippines#cite_ref-702
# Link Element '"Philippines"' With URL https://books.google.com/books?id=nZUarsZyzokC With rel attribute nofollow
# Link Element 'Scarecrow Press' With URL https://en.wikipedia.org/wiki/Scarecrow_Press
# Link Element '291' With URL https://books.google.com/books?id=nZUarsZyzokC&pg=PA291 With rel attribute nofollow
# Link Element 'ISBN' With URL https://en.wikipedia.org/wiki/ISBN_(identifier)
# Link Element '978-0-8108-7506-7' With URL https://en.wikipedia.org/wiki/Special:BookSources/978-0-8108-7506-7
# Link Element '^' With URL https://en.wikipedia.org/wiki/Philippines#cite_ref-703
# Link Element '"Pacquiao named fighter of the decade"' With URL https://web.archive.org/web/20100605173159/https://www.reuters.com/article/idUSTRE6541BX20100605 With rel attribute nofollow
# Link Element 'Reuters' With URL https://en.wikipedia.org/wiki/Reuters
# Link Element 'the original' With URL https://www.reuters.com/article/idUSTRE6541BX20100605 With rel attribute nofollow
# Link Element '^' With URL https://en.wikipedia.org/wiki/Philippines#cite_ref-704
# Link Element 'An Act Declaring Arnis as the National Martial Art and Sport of the Philippines' With URL https://web.archive.org/web/20170810035837/https://www.officialgazette.gov.ph/2009/12/11/republic-act-no-9850/ With rel attribute nofollow
# Link Element 'Official Gazette of the Republic of the Philippines' With URL https://en.wikipedia.org/wiki/Official_Gazette_of_the_Republic_of_the_Philippines
# Link Element 'the original' With URL https://www.officialgazette.gov.ph/2009/12/11/republic-act-no-9850/ With rel attribute nofollow
# Link Element '^' With URL https://en.wikipedia.org/wiki/Philippines#cite_ref-705
# Link Element 'The Cockfight: A Casebook' With URL https://books.google.com/books?id=Wy5VqKSYt8IC With rel attribute nofollow
# Link Element 'University of Wisconsin Press' With URL https://en.wikipedia.org/wiki/University_of_Wisconsin_Press
# Link Element '136–137' With URL https://books.google.com/books?id=Wy5VqKSYt8IC&pg=PA136 With rel attribute nofollow
# Link Element 'ISBN' With URL https://en.wikipedia.org/wiki/ISBN_(identifier)
# Link Element '978-0-299-14054-0' With URL https://en.wikipedia.org/wiki/Special:BookSources/978-0-299-14054-0
# Link Element '^' With URL https://en.wikipedia.org/wiki/Philippines#cite_ref-706
# Link Element '"Philippine esports gains traction in 2022"' With URL https://web.archive.org/web/20230410070659/https://www.philstar.com/sports/2022/12/29/2234051/philippine-esports-gains-traction-2022 With rel attribute nofollow
# Link Element 'The Philippine Star' With URL https://en.wikipedia.org/wiki/The_Philippine_Star
# Link Element 'the original' With URL https://www.philstar.com/sports/2022/12/29/2234051/philippine-esports-gains-traction-2022 With rel attribute nofollow
# Link Element 'a' With URL https://en.wikipedia.org/wiki/Philippines#cite_ref-Booc-2019_707-0
# Link Element 'b' With URL https://en.wikipedia.org/wiki/Philippines#cite_ref-Booc-2019_707-1
# Link Element '"The Traditional Filipino Games: Status Check Among Generation Z"' With URL https://doi.org/10.15863%2FTAS.2019.10.78.25 With rel attribute nofollow
# Link Element 'doi' With URL https://en.wikipedia.org/wiki/Doi_(identifier)
# Link Element '10.15863/TAS.2019.10.78.25' With URL https://doi.org/10.15863%2FTAS.2019.10.78.25 With rel attribute nofollow
# Link Element '^' With URL https://en.wikipedia.org/wiki/Philippines#cite_ref-708
# Link Element '"The Empirical Change of Playing Habits among Children"' With URL https://doi.org/10.11594%2Fijmaber.03.02.15 With rel attribute nofollow
# Link Element 'doi' With URL https://en.wikipedia.org/wiki/Doi_(identifier)
# Link Element '10.11594/ijmaber.03.02.15' With URL https://doi.org/10.11594%2Fijmaber.03.02.15 With rel attribute nofollow
# Link Element '^' With URL https://en.wikipedia.org/wiki/Philippines#cite_ref-709
# Link Element '"History made as PH Azkals advance to 2019 AFC Asian Cup after beating Tajiks"' With URL https://web.archive.org/web/20201109034121/https://sports.inquirer.net/290641/ph-azkals-advance-2019-afc-asia-cup-beating-tajiks With rel attribute nofollow
# Link Element 'Philippine Daily Inquirer' With URL https://en.wikipedia.org/wiki/Philippine_Daily_Inquirer
# Link Element 'the original' With URL https://sports.inquirer.net/290641/ph-azkals-advance-2019-afc-asia-cup-beating-tajiks With rel attribute nofollow
# Link Element '^' With URL https://en.wikipedia.org/wiki/Philippines#cite_ref-710
# Link Element '"Herstory: Filipinas outlast Chinese Taipei to seize historic Women's World Cup berth"' With URL https://web.archive.org/web/20220130170703/https://www.philstar.com/sports/2022/01/31/2157582/herstory-filipinas-outlast-chinese-taipei-seize-historic-womens-world-cup-berth With rel attribute nofollow
# Link Element 'The Philippine Star' With URL https://en.wikipedia.org/wiki/The_Philippine_Star
# Link Element 'the original' With URL https://www.philstar.com/sports/2022/01/31/2157582/herstory-filipinas-outlast-chinese-taipei-seize-historic-womens-world-cup-berth With rel attribute nofollow
# Link Element '^' With URL https://en.wikipedia.org/wiki/Philippines#cite_ref-711
# Link Element 'Mallon, Bill' With URL https://en.wikipedia.org/wiki/Bill_Mallon
# Link Element '"Philippines, The (PHI)"' With URL https://books.google.com/books?id=uCN1CQAAQBAJ With rel attribute nofollow
# Link Element 'Rowman & Littlefield' With URL https://en.wikipedia.org/wiki/Rowman_%26_Littlefield
# Link Element '473' With URL https://books.google.com/books?id=uCN1CQAAQBAJ&pg=PA473 With rel attribute nofollow
# Link Element 'ISBN' With URL https://en.wikipedia.org/wiki/ISBN_(identifier)
# Link Element '978-1-4422-4860-1' With URL https://en.wikipedia.org/wiki/Special:BookSources/978-1-4422-4860-1
# Link Element '^' With URL https://en.wikipedia.org/wiki/Philippines#cite_ref-712
# Link Element '"U.S. says 60 nations will join boycott"' With URL https://books.google.com/books?id=DAFJAQAAIAAJ With rel attribute nofollow
# Link Element 'United States Department of State' With URL https://en.wikipedia.org/wiki/United_States_Department_of_State
# Link Element 'Bureau of African Affairs' With URL https://en.wikipedia.org/wiki/Bureau_of_African_Affairs
# Link Element '24' With URL https://books.google.com/books?id=DAFJAQAAIAAJ&pg=RA19-PA24 With rel attribute nofollow
# Link Element '^' With URL https://en.wikipedia.org/wiki/Philippines#cite_ref-713
# Link Element '"Winter Olympics: Even outsiders can break the ice"' With URL https://web.archive.org/web/20180224080645/https://www.straitstimes.com/sport/even-outsiders-can-break-the-ice With rel attribute nofollow
# Link Element 'The Straits Times' With URL https://en.wikipedia.org/wiki/The_Straits_Times
# Link Element 'the original' With URL https://www.straitstimes.com/sport/even-outsiders-can-break-the-ice With rel attribute nofollow
# Link Element '^' With URL https://en.wikipedia.org/wiki/Philippines#cite_ref-714
# Link Element 'The XI Olympic Winter Games; Les XI Jeux Olympiques d'hiver; Sapporo, 1972' With URL https://web.archive.org/web/20080226202605/http://www.la84foundation.org/6oic/OfficialReports/1972/orw1972.pdf With rel attribute nofollow
# Link Element 'OCLC' With URL https://en.wikipedia.org/wiki/OCLC_(identifier)
# Link Element '842416' With URL https://search.worldcat.org/oclc/842416 With rel attribute nofollow
# Link Element 'the original' With URL http://www.la84foundation.org/6oic/OfficialReports/1972/orw1972.pdf With rel attribute nofollow
# Link Element 'LA84 Foundation' With URL https://en.wikipedia.org/wiki/LA84_Foundation
# Link Element '^' With URL https://en.wikipedia.org/wiki/Philippines#cite_ref-715
# Link Element 'Araullo, Atom' With URL https://en.wikipedia.org/wiki/Atom_Araullo
# Link Element '"Anatomy of Philippines' first Olympic gold medal"' With URL https://web.archive.org/web/20211104071057/https://pcij.org/article/7371/anatomy-of-philippines-first-olympic-gold-medal With rel attribute nofollow
# Link Element 'Philippine Center for Investigative Journalism' With URL https://en.wikipedia.org/wiki/Philippine_Center_for_Investigative_Journalism
# Link Element 'the original' With URL https://pcij.org/article/7371/anatomy-of-philippines-first-olympic-gold-medal With rel attribute nofollow
# Link Element 'Bibliography of the Philippines' With URL https://en.wikipedia.org/wiki/Bibliography_of_the_Philippines
# Link Element 'sister projects' With URL https://en.wikipedia.org/wiki/Wikipedia:Wikimedia_sister_projects
# Link Element 'Definitions' With URL https://en.wiktionary.org/wiki/Special:Search/Philippines
# Link Element 'Media' With URL https://commons.wikimedia.org/wiki/Pilipinas_/_Philippines
# Link Element 'News' With URL https://en.wikinews.org/wiki/Category:Philippines
# Link Element 'Quotations' With URL https://en.wikiquote.org/wiki/Philippines
# Link Element 'Texts' With URL https://en.wikisource.org/wiki/Special:Search/Philippines
# Link Element 'Textbooks' With URL https://en.wikibooks.org/wiki/Special:Search/Philippines
# Link Element 'Resources' With URL https://en.wikiversity.org/wiki/Special:Search/Philippines
# Link Element 'Travel information' With URL https://en.wikivoyage.org/wiki/Philippines
# Link Element 'Government of the Philippines' With URL https://www.gov.ph/ With rel attribute nofollow
# Link Element 'Archived' With URL https://web.archive.org/web/20070609185330/http://www.op.gov.ph/ With rel attribute nofollow
# Link Element 'Wayback Machine' With URL https://en.wikipedia.org/wiki/Wayback_Machine
# Link Element 'Official Gazette' With URL https://www.officialgazette.gov.ph/ With rel attribute nofollow
# Link Element 'Archived' With URL https://web.archive.org/web/20220114130536/https://www.officialgazette.gov.ph/ With rel attribute nofollow
# Link Element 'Wayback Machine' With URL https://en.wikipedia.org/wiki/Wayback_Machine
# Link Element '"Philippines"' With URL https://www.bbc.co.uk/news/world-asia-15521300 With rel attribute nofollow
# Link Element '"Philippines"' With URL https://web.archive.org/web/20110521230339/http://ucblibraries.colorado.edu/govpubs/for/philippines.htm With rel attribute nofollow
# Link Element 'Philippines' With URL https://www.openstreetmap.org/relation/443174 With rel attribute nofollow
# Link Element 'OpenStreetMap' With URL https://en.wikipedia.org/wiki/OpenStreetMap
# Link Element 'Wikimedia Atlas of Philippines' With URL https://commons.wikimedia.org/wiki/Atlas_of_Philippines
# Link Element 'Filipiniana.net – Free digital library and a research portal' With URL https://web.archive.org/web/20081217085143/http://filipiniana.net/ With rel attribute nofollow
# Link Element 'v' With URL https://en.wikipedia.org/wiki/Template:Philippines_topics
# Link Element 't' With URL https://en.wikipedia.org/wiki/Template_talk:Philippines_topics
# Link Element 'e' With URL https://en.wikipedia.org/wiki/Special:EditPage/Template:Philippines_topics
# Link Element 'Philippines' Without URL
# Link Element 'Authority control databases' With URL https://en.wikipedia.org/wiki/Help:Authority_control
# Link Element Without Name With URL https://www.wikidata.org/wiki/Q928#identifiers
# Link Element 'Categories' With URL https://en.wikipedia.org/wiki/Help:Category
# Link Element 'Philippines' With URL https://en.wikipedia.org/wiki/Category:Philippines
# Link Element 'Countries and territories where English is an official language' With URL https://en.wikipedia.org/wiki/Category:Countries_and_territories_where_English_is_an_official_language
# Link Element 'Former colonies in Asia' With URL https://en.wikipedia.org/wiki/Category:Former_colonies_in_Asia
# Link Element 'Former Spanish colonies' With URL https://en.wikipedia.org/wiki/Category:Former_Spanish_colonies
# Link Element 'Island countries' With URL https://en.wikipedia.org/wiki/Category:Island_countries
# Link Element 'Maritime Southeast Asia' With URL https://en.wikipedia.org/wiki/Category:Maritime_Southeast_Asia
# Link Element 'Member states of ASEAN' With URL https://en.wikipedia.org/wiki/Category:Member_states_of_ASEAN
# Link Element 'Member states of the United Nations' With URL https://en.wikipedia.org/wiki/Category:Member_states_of_the_United_Nations
# Link Element 'Newly industrializing countries' With URL https://en.wikipedia.org/wiki/Category:Newly_industrializing_countries
# Link Element 'Republics' With URL https://en.wikipedia.org/wiki/Category:Republics
# Link Element 'Southeast Asian countries' With URL https://en.wikipedia.org/wiki/Category:Southeast_Asian_countries
# Link Element 'Spanish East Indies' With URL https://en.wikipedia.org/wiki/Category:Spanish_East_Indies
# Link Element 'States and territories established in 1565' With URL https://en.wikipedia.org/wiki/Category:States_and_territories_established_in_1565
# Link Element 'States and territories established in 1898' With URL https://en.wikipedia.org/wiki/Category:States_and_territories_established_in_1898
# Link Element 'States and territories established in 1946' With URL https://en.wikipedia.org/wiki/Category:States_and_territories_established_in_1946
# Link Element 'Volcanic arc islands' With URL https://en.wikipedia.org/wiki/Category:Volcanic_arc_islands
# Link Element 'Countries in Asia' With URL https://en.wikipedia.org/wiki/Category:Countries_in_Asia
# Link Element 'Former Japanese colonies' With URL https://en.wikipedia.org/wiki/Category:Former_Japanese_colonies
# Link Element 'Creative Commons Attribution-ShareAlike 4.0 License' With URL https://en.wikipedia.org/wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License
# Link Element 'Terms of Use' With URL https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Terms_of_Use
# Link Element 'Privacy Policy' With URL https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy
# Link Element 'Wikimedia Foundation, Inc.' With URL https://wikimediafoundation.org/ With rel attribute nofollow
# Link Element 'Privacy policy' With URL https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy
# Link Element 'About Wikipedia' With URL https://en.wikipedia.org/wiki/Wikipedia:About
# Link Element 'Disclaimers' With URL https://en.wikipedia.org/wiki/Wikipedia:General_disclaimer
# Link Element 'Contact Wikipedia' With URL https://en.wikipedia.org/wiki/Wikipedia:Contact_us
# Link Element 'Code of Conduct' With URL https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Universal_Code_of_Conduct
# Link Element 'Developers' With URL https://developer.wikimedia.org/
# Link Element 'Statistics' With URL https://stats.wikimedia.org/#/en.wikipedia.org
# Link Element 'Cookie statement' With URL https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Cookie_statement
# Link Element 'Mobile view' With URL https://en.m.wikipedia.org/w/index.php?title=Philippines&mobileaction=toggle_view_mobile
# Link Element Without Name With URL https://wikimediafoundation.org/
# Link Element Without Name With URL https://www.mediawiki.org/

# %%
driver = webdriver.Firefox()
driver.get("https://en.wikipedia.org/wiki/Philippines")

visible_text = []
# Heading Elements
for level in range(1, 7):  # HTML has 6 levels of headings (h1 to h6)
    headings = driver.find_elements(By.TAG_NAME,f"h{level}")
    for heading in headings:
        if heading.is_displayed():
            store = f"Heading Element (h{level}): '{heading.text}'"
            # Store
            visible_text.append(store)
# Paragraph Elements
paragraphs = driver.find_elements(By.TAG_NAME,"p")
for paragraph in paragraphs:
    if paragraph.is_displayed():
        store = f"Paragraph Element: '{paragraph.text}'"
        # Store
        visible_text.append(store)

driver.quit()

print_list(visible_text)

# %%
driver = webdriver.Firefox()
driver.get("https://en.wikipedia.org/wiki/Philippines")

visible_text_inputs = []
input_tags = driver.find_elements(By.TAG_NAME,"input")
for input_tag in input_tags:
    if input_tag.is_displayed():
        # Basic Attributes
        input_field_name = f"Input Field Element: '{input_tag.get_attribute('name')}'" if input_tag.get_attribute('name') != None else "Without Name"
        input_field_type = f"With Type {input_tag.get_attribute('type')}" if input_tag.get_attribute('name') != None else "Without Type"
        # Additional Attributes
        input_field_value = f"With Value {input_tag.get_attribute('value')}" if input_tag.get_attribute('name') != None else "Without Value"
        input_field_placeholder = f"With Placeholder '{input_tag.get_attribute('placeholder')}'" if input_tag.get_attribute('name') != None else "Without Placeholder"
        input_field_readonly = f"Is Readonly" if input_tag.get_attribute('readonly') != None else "Is Editable"
        input_field_disabled = f"Is Not Clickable" if input_tag.get_attribute('disabled') != None else "Is Clickable"
        input_field_required = f"Is Required" if input_tag.get_attribute('required') != None else "Not Required"
        input_field_autocomplete = f"Is Autocomplete" if input_tag.get_attribute('autocomplete') != None else "Not Autocomplete"

        # Store based on type
        if (input_tag.get_attribute('type') == "submit"):
            store = f"Form Submit Button Element: {input_tag.get_attribute("name")} {input_field_disabled}"
        else:
            store = f"{input_field_name} {input_field_type} {input_field_value} {input_field_placeholder} {input_field_readonly} {input_field_disabled} {input_field_disabled} {input_field_autocomplete}"
        visible_text_inputs.append(store)

driver.quit()

print_list(visible_text_inputs)
# Out:
# Input Field Element: 'search' With Type search With Value  With Placeholder 'Search Wikipedia' Is Editable Is Clickable Is Clickable Is Autocomplete

# %% [markdown]
# ##### V1 Resulting Version

# %%
## SCRAPER IMPORTS ##
from selenium import webdriver

import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By

## GET URL FUNCTION (non UI version) ##
def get_url():
    return input("Enter Website URL: ")

# DATA SCRAPING FUNCTION
def data_scrape(url):
    # Setup Selenium Webdriver
    # TODO : For V2 Add other drivers according to user settings. Detect user browser and use that as driver potentially
    driver = webdriver.Firefox()
    # Setup Return Data
    data = []

    # Open the website
    driver.get(url)
    
    ## GET UI ELEMENTS (must be visible) ##

    # BUTTONS
    buttons = driver.find_elements(By.CSS_SELECTOR, "button")
    for button in buttons:
        if button.is_displayed():
            # Button Element Attributes
            button_text = f"Button Element '{button.text}'" if (button.text != None and button.text != "") else "Button Element Without Name"
            button_size = f"With Size Attribute {button.size}" if button.size != None else "Without Size Attribute"
            button_color = f"With Background Color {button.value_of_css_property("background-color")}" if button.value_of_css_property("background-color") != None else "Without Background Color"
            button_enabled = "and the button is Clickable" if button.is_enabled() else "and the button is not Clickable"
            
            # Store Button Element
            store = f"{button_text} {button_size} {button_color} {button_enabled}"
            data.append(store)
            
    # LINKS
    links = driver.find_elements(By.TAG_NAME,"a")
    for link in links:
        if link.is_displayed():
            # Link Element Attributes
            link_text = f"Link Element '{link.text}'" if (link.text != None and link.text != "") else "Link Element Without Name"
            link_url = f"With URL {link.get_attribute('href')}" if link.get_attribute('href') != None else "Without URL"
            # Additional Attributes
            link_rel = f"With rel attribute {link.get_attribute('rel')}" if link.get_attribute('rel') != None and link.get_attribute('rel') != "" else ""
            link_target = f"With target attribute {link.get_attribute('target')}" if link.get_attribute('target') != None and link.get_attribute('target') != "" else ""
            link_download = f"This is a download link to document {link.get_attribute('download')}" if link.get_attribute('download') != None and link.get_attribute('download') != "" else ""
            
            # Store Link Element
            store = f"{link_text} {link_url} {link_rel} {link_target} {link_download}"
            data.append(store)

    # VISIBLE TEXT
    # Heading Elements
    for level in range(1, 7):  # HTML has 6 levels of headings (h1 to h6)
        headings = driver.find_elements(By.TAG_NAME,f"h{level}")
        for heading in headings:
            if heading.is_displayed():
                store = f"Heading Element (h{level}): '{heading.text}'"
                # Store
                data.append(store)
    # Paragraph Elements
    paragraphs = driver.find_elements(By.TAG_NAME,"p")
    for paragraph in paragraphs:
        if paragraph.is_displayed():
            store = f"Paragraph Element: '{paragraph.text}'"
            # Store
            data.append(store)

    # INPUT
    input_tags = driver.find_elements(By.TAG_NAME,"input")
    for input_tag in input_tags:
        if input_tag.is_displayed():
            # Basic Attributes
            input_field_name = f"Input Field Element: '{input_tag.get_attribute('name')}'" if input_tag.get_attribute('name') != None else "Without Name"
            input_field_type = f"With Type {input_tag.get_attribute('type')}" if input_tag.get_attribute('name') != None else "Without Type"
            # Additional Attributes
            input_field_value = f"With Value {input_tag.get_attribute('value')}" if input_tag.get_attribute('name') != None else "Without Value"
            input_field_placeholder = f"With Placeholder '{input_tag.get_attribute('placeholder')}'" if input_tag.get_attribute('name') != None else "Without Placeholder"
            input_field_readonly = f"Is Readonly" if input_tag.get_attribute('readonly') != None else "Is Editable"
            input_field_disabled = f"Is Not Clickable" if input_tag.get_attribute('disabled') != None else "Is Clickable"
            input_field_required = f"Is Required" if input_tag.get_attribute('required') != None else "Not Required"
            input_field_autocomplete = f"Is Autocomplete" if input_tag.get_attribute('autocomplete') != None else "Not Autocomplete"

            # Store based on type
            if (input_tag.get_attribute('type') == "submit"):
                store = f"Form Submit Button Element: {input_tag.get_attribute("name")} {input_field_disabled}"
            else:
                store = f"{input_field_name} {input_field_type} {input_field_required} {input_field_value} {input_field_placeholder} {input_field_readonly} {input_field_disabled} {input_field_autocomplete}"
            data.append(store)
            
    # Close the browser
    driver.quit()
    
    ## RETURN COMPILED ELEMENT DATA ##
    return data

# %% [markdown]
# ##### Version 2: Polished Context

# %%
# TODO :
# Polish Conditionals' results (make it more understandable to the llm)
# Consider adding better context to llm prompt

# %% [markdown]
# ##### Back to the drawing board : individual testing

# %%
# Webdriver testing

def setup_driver():
    try :
        driver = webdriver.Firefox() # Default with Firefox
    except Exception:
        try : 
            driver = webdriver.Chrome() # Default with Chrome
        except Exception:
            try : 
                driver = webdriver.Edge() # Default with Edge
            except Exception:
                print("Error. No usable browser found for scraping")
    
    return driver

# %%
"""
Button Element
Name : 
Size Attribute : large/small, to be specific : {}
Background Color : 
Is Clickable : 
"""

# %%
# BUTTONS
buttons = driver.find_elements(By.CSS_SELECTOR, "button")
for button in buttons:
    if button.is_displayed():
        # Button Element Attributes
        button_text = f"Button Element '{button.text}'" if (button.text != None and button.text != "") else "Button Element Without Name"
        button_size = f"With Size Attribute {button.size}" if button.size != None else "Without Size Attribute"
        button_color = f"With Background Color {button.value_of_css_property("background-color")}" if button.value_of_css_property("background-color") != None else "Without Background Color"
        button_enabled = "and the button is Clickable" if button.is_enabled() else "and the button is not Clickable"
        
        # Store Button Element
        store = f"{button_text} {button_size} {button_color} {button_enabled}"

# %%
    # LINKS
links = driver.find_elements(By.TAG_NAME,"a")
for link in links:
    if link.is_displayed():
        # Link Element Attributes
        link_text = f"Link Element '{link.text}'" if (link.text != None and link.text != "") else "Link Element Without Name"
        link_url = f"With URL {link.get_attribute('href')}" if link.get_attribute('href') != None else "Without URL"
        # Additional Attributes
        link_rel = f"With rel attribute {link.get_attribute('rel')}" if link.get_attribute('rel') != None and link.get_attribute('rel') != "" else ""
        link_target = f"With target attribute {link.get_attribute('target')}" if link.get_attribute('target') != None and link.get_attribute('target') != "" else ""
        link_download = f"This is a download link to document {link.get_attribute('download')}" if link.get_attribute('download') != None and link.get_attribute('download') != "" else ""
        
        # Store Link Element
        store = f"{link_text} {link_url} {link_rel} {link_target} {link_download}"

# %%
# VISIBLE TEXT
# Heading Elements
for level in range(1, 7):  # HTML has 6 levels of headings (h1 to h6)
    headings = driver.find_elements(By.TAG_NAME,f"h{level}")
    for heading in headings:
        if heading.is_displayed():
            store = f"Heading Element (h{level}): '{heading.text}'"
# Paragraph Elements
paragraphs = driver.find_elements(By.TAG_NAME,"p")
for paragraph in paragraphs:
    if paragraph.is_displayed():
        store = f"Paragraph Element: '{paragraph.text}'"

# %%
# INPUT
input_tags = driver.find_elements(By.TAG_NAME,"input")
for input_tag in input_tags:
    if input_tag.is_displayed():
        # Basic Attributes
        input_field_name = f"Input Field Element: '{input_tag.get_attribute('name')}'" if input_tag.get_attribute('name') != None else "Without Name"
        input_field_type = f"With Type {input_tag.get_attribute('type')}" if input_tag.get_attribute('name') != None else "Without Type"
        # Additional Attributes
        input_field_value = f"With Value {input_tag.get_attribute('value')}" if input_tag.get_attribute('name') != None else "Without Value"
        input_field_placeholder = f"With Placeholder '{input_tag.get_attribute('placeholder')}'" if input_tag.get_attribute('name') != None else "Without Placeholder"
        input_field_readonly = f"Is Readonly" if input_tag.get_attribute('readonly') != None else "Is Editable"
        input_field_disabled = f"Is Not Clickable" if input_tag.get_attribute('disabled') != None else "Is Clickable"
        input_field_required = f"Is Required" if input_tag.get_attribute('required') != None else "Not Required"
        input_field_autocomplete = f"Is Autocomplete" if input_tag.get_attribute('autocomplete') != None else "Not Autocomplete"

        # Store based on type
        if (input_tag.get_attribute('type') == "submit"):
            store = f"Form Submit Button Element: {input_tag.get_attribute("name")} {input_field_disabled}"
        else:
            store = f"{input_field_name} {input_field_type} {input_field_required} {input_field_value} {input_field_placeholder} {input_field_readonly} {input_field_disabled} {input_field_autocomplete}"
