# %% [markdown]
# ### Dataset Generation
# - Consists of scraper, prompt generator, and table generator. Because of this, development of prompt generator, table generator, and scraper are partially based on the development of dataset generation notebook (and vice versa)
# ### How To Use
# - Assuming you have all dependencies, just run all cells and give the website URL (.org/.edu/.gov)
# - I will comment out all unused cells so it is safe to run all
# ### Dependencies
# - Selenium
# - Ollama (and Llama 3.1 8b)
# - Pandas

# %% [markdown]
# #### Version 1: [Use This Until V2]

# %% [markdown]
# ##### Functions

# %%
## SCRAPER IMPORTS ##
from selenium import webdriver

import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By

## GET URL FUNCTION (non UI version) ##
def get_url():
    return input("Enter Website URL: ")

# DATA SCRAPING FUNCTION
def data_scrape(url):
    # Setup Selenium Webdriver
    # TODO : For V2 Add other drivers according to user settings. Detect user browser and use that as driver potentially
    driver = webdriver.Firefox()
    # Setup Return Data
    data = []

    # Open the website
    driver.get(url)
    
    ## GET UI ELEMENTS (must be visible) ##

    # BUTTONS
    buttons = driver.find_elements(By.CSS_SELECTOR, "button")
    for button in buttons:
        if button.is_displayed():
            # Button Element Attributes
            button_text = f"Button Element '{button.text}'" if (button.text != None and button.text != "") else "Button Element Without Name"
            button_size = f"With Size Attribute {button.size}" if button.size != None else "Without Size Attribute"
            button_color = f"With Background Color {button.value_of_css_property("background-color")}" if button.value_of_css_property("background-color") != None else "Without Background Color"
            button_enabled = "and the button is Clickable" if button.is_enabled() else "and the button is not Clickable"
            
            # Store Button Element
            store = f"{button_text} {button_size} {button_color} {button_enabled}"
            data.append(store)
            
    # LINKS
    links = driver.find_elements(By.TAG_NAME,"a")
    for link in links:
        if link.is_displayed():
            # Link Element Attributes
            link_text = f"Link Element '{link.text}'" if (link.text != None and link.text != "") else "Link Element Without Name"
            link_url = f"With URL {link.get_attribute('href')}" if link.get_attribute('href') != None else "Without URL"
            # Additional Attributes
            link_rel = f"With rel attribute {link.get_attribute('rel')}" if link.get_attribute('rel') != None and link.get_attribute('rel') != "" else ""
            link_target = f"With target attribute {link.get_attribute('target')}" if link.get_attribute('target') != None and link.get_attribute('target') != "" else ""
            link_download = f"This is a download link to document {link.get_attribute('download')}" if link.get_attribute('download') != None and link.get_attribute('download') != "" else ""
            
            # Store Link Element
            store = f"{link_text} {link_url} {link_rel} {link_target} {link_download}"
            data.append(store)

    # VISIBLE TEXT
    # Heading Elements
    for level in range(1, 7):  # HTML has 6 levels of headings (h1 to h6)
        headings = driver.find_elements(By.TAG_NAME,f"h{level}")
        for heading in headings:
            if heading.is_displayed():
                store = f"Heading Element (h{level}): '{heading.text}'"
                # Store
                data.append(store)
    # Paragraph Elements
    paragraphs = driver.find_elements(By.TAG_NAME,"p")
    for paragraph in paragraphs:
        if paragraph.is_displayed():
            store = f"Paragraph Element: '{paragraph.text}'"
            # Store
            data.append(store)

    # INPUT
    input_tags = driver.find_elements(By.TAG_NAME,"input")
    for input_tag in input_tags:
        if input_tag.is_displayed():
            # Basic Attributes
            input_field_name = f"Input Field Element: '{input_tag.get_attribute('name')}'" if input_tag.get_attribute('name') != None else "Without Name"
            input_field_type = f"With Type {input_tag.get_attribute('type')}" if input_tag.get_attribute('name') != None else "Without Type"
            # Additional Attributes
            input_field_value = f"With Value {input_tag.get_attribute('value')}" if input_tag.get_attribute('name') != None else "Without Value"
            input_field_placeholder = f"With Placeholder '{input_tag.get_attribute('placeholder')}'" if input_tag.get_attribute('name') != None else "Without Placeholder"
            input_field_readonly = f"Is Readonly" if input_tag.get_attribute('readonly') != None else "Is Editable"
            input_field_disabled = f"Is Not Clickable" if input_tag.get_attribute('disabled') != None else "Is Clickable"
            input_field_required = f"Is Required" if input_tag.get_attribute('required') != None else "Not Required"
            input_field_autocomplete = f"Is Autocomplete" if input_tag.get_attribute('autocomplete') != None else "Not Autocomplete"

            # Store based on type
            if (input_tag.get_attribute('type') == "submit"):
                store = f"Form Submit Button Element: {input_tag.get_attribute("name")} {input_field_disabled}"
            else:
                store = f"{input_field_name} {input_field_type} {input_field_required} {input_field_value} {input_field_placeholder} {input_field_readonly} {input_field_disabled} {input_field_disabled} {input_field_autocomplete}"
            data.append(store)
            
    # Close the browser
    driver.quit()
    
    ## RETURN COMPILED ELEMENT DATA ##
    return data

## PROMPT GENERATOR (+LLM) IMPORTS ##
import langchain
from langchain_ollama.llms import OllamaLLM
from langchain_core.prompts import ChatPromptTemplate

template = """
You are a quality assurance expert that generates functional test cases for websites. You take in a UI element and you generate a functional test case for usability.

Some UI elements have a link attached to them and other properties.
ONLY output in the following format: 
"Objective"~"Preconditions"~"Test Steps"~"Expected Result"
DO NOT output any other text. DO NOT output 'Here are the test cases...'

Example Input:
Link Element: Home with URL : https://bicol-u.edu.ph/
Link Element: Academics with URL : https://bicol-u.edu.ph/#
Link Element 'Battle of New Orleans' With URL https://en.wikipedia.org/wiki/Battle_of_New_Orleans   
...

Example Output:
"Verify the functionality of the Link Element 'Home'"~"The user is on the webpage 'https://bicol-u.edu.ph/'"~"'1. User navigates to the webpage \'https://bicol-u.edu.ph/\'' '2. Click on Link Element \'Home\'' '3. Verify if the webpage opens in a new tab/window.'"~"Webpage 'https://bicol-u.edu.ph/' should open in a new tab/window."
"Verify the functionality of the Link Element 'Academics'"~"The user is on the webpage 'https://bicol-u.edu.ph/'"~"'1. User navigates to the webpage \'https://bicol-u.edu.ph/\'' '2. Click on Link Element \'Academics\'' '3. Verify if the link url changes to \'https://bicol-u.edu.ph/#\'' '4. Verify if a dropdown below \'Academics\' is visible'"~"A dropdown should show below 'Academics', but the webpage does not change"
"Verify the functionality of the Link Element 'Battle of New Orleans'"~"The user is on the webpage 'https://en.wikipedia.org/'"~"'1. User navigates to the webpage 'https://en.wikipedia.org/' '' '2. Click on Link Element 'Battle of New Orleans'' '3. Verify if the link url changes to 'https://en.wikipedia.org/wiki/Battle_of_New_Orleans' '4. Verify if the webpage opens in a new tab/window'"~"Webpage 'https://en.wikipedia.org/wiki/Battle_of_New_Orleans/' should open in a new tab/window."
...

Here is the UI element : {question}
"""

# LOAD MODEL CHAIN
def load_model_chain(template : str =  template, model_str : str = "llama3.1"):
    prompt = ChatPromptTemplate.from_template(template)
    model = OllamaLLM(model=model_str)
    chain = prompt | model
    return chain

# CREATE TEST CASE DATA
def create_test_cases(data, model_str : str = "llama3.1" , template : str = template):
    
    # Load LLM Chain
    chain = load_model_chain(template, model_str)

    # Return Data
    return_data = []
    
    for item in data:
        return_data.append(chain.invoke({"question": str(item)}))
        # LLM Reset To Free Up Context
        chain = load_model_chain(template, model_str)

    return return_data

## TABLE GENERATOR IMPORTS ##
import pandas as pd

# INITIALIZE TABLE DATAFRAME
def dataframe_init(data):
    df = pd.DataFrame(dict([(key, pd.Series(value)) for key, value in data.items()]))
    return df

# CSV GENERATOR
def csv_from_test_case_batches(filename, data):
    cols = dataframe_init(data)
    cols.to_csv(f"{filename}.csv", sep='\t', encoding='utf-8', index=False, header=True)

## CREATE THE FINE TUNING DATASET ##
def create_fine_tuning_dataset(scraped_data, llm_output):
    # Dataset Generator : Resulting Dataset Columns / Parameters
    out_data = llm_output # LLM Output
    in_data = scraped_data # Scraped UI Element
    instruction_data = []
    i = 0
    while (i < len(scraped_data)):
        template = f"####Question:\n Generate test case for the following UI element: {in_data[i]}"
        instruction_data.append(template)
        i+=1

    data = {"output" : out_data, 
            "input" : in_data, 
            "instruction" : instruction_data}
    csv_from_test_case_batches("fine_tuning_dataset", data)
    return dataframe_init(data)

# %%
import time # for checking runtime
# TODO : Add a looping feature for scraping multiple websites
# IDEA : We Developers Hardcode a List of URLs, list of URLS are fed to the loop, and generates multiple csv files 

## MAIN PROGRAM ##
print("Welcome to Dataset Generator V1")

## Input URL
start = time.time()
scraped_data = data_scrape(get_url())
end = time.time()
print(f"Scraping Finished In : {(end-start) * 10**3}, ms")

## Create Test Cases
print("This will take a while to complete: Please wait by doing other things. You will receive a message once generation is complete.")
start = time.time()
llm_output = create_test_cases(scraped_data)
end = time.time()
print(f"Generation Finished In : {(end-start) * 10**3}, ms")

## Create Fine Tuning Dataset
fine_tuning_dataset = create_fine_tuning_dataset(scraped_data, llm_output)
print("Dataset is Generated as a CSV File. Please rename it before running this notebook again")
# Out:
# Welcome to Dataset Generator V1
# Scraping Finished In : 63689.451932907104, ms
# This will take a while to complete: Please wait by doing other things. You will receive a message once generation is complete.
# Generation Finished In : 2275197.4651813507, ms
# Dataset is Generated as a CSV File. Please rename it before running this notebook again

# %%
import time # for checking runtime
# TODO : Add a looping feature for scraping multiple websites
# IDEA : We Developers Hardcode a List of URLs, list of URLS are fed to the loop, and generates multiple csv files 

# System Proper Parameters
def create_table_dataset(llm_output):
    # TODO : After Dataset Generator Development

    id = []
    objective = []
    precondition = []
    test_steps = []
    expected_result = []
    actual_result = []

    i = 0
    for test_case in llm_output:
        split_test_case = test_case.split('~')

        # Test Case ID
        id.append(i+1)

        # Test Case Objective
        objective.append(split_test_case[0])

        # Test Case Precondition
        precondition.append(split_test_case[1])

        # Test Case Steps 
        test_steps.append(split_test_case[2])

        # Test Case Expected Output
        expected_result.append(split_test_case[3])

        # Test Case Actual Result
        actual_result.append("Pass/Fail")

        i+=1

    data = {"Test Case ID" : id,
            "Objective" : objective,
            "Precondition" : precondition,
            "Test Steps" : test_steps,
            "Expected Result" : expected_result,
            "Actual Result" : actual_result}

    return dataframe_init(data)

## MAIN PROGRAM ##
print("Welcome to Dataset Generator V1")

## Input URL
start = time.time()
scraped_data = data_scrape(get_url())
end = time.time()
print(f"Scraping Finished In : {(end-start) * 10**3}, ms")

## Create Test Cases
print("This will take a while to complete: Please wait by doing other things. You will receive a message once generation is complete.")
start = time.time()
llm_output = create_test_cases(scraped_data)
end = time.time()
print(f"Generation Finished In : {(end-start) * 10**3}, ms")
# Out:
# Welcome to Dataset Generator V1
# Scraping Finished In : 48011.70563697815, ms
# This will take a while to complete: Please wait by doing other things. You will receive a message once generation is complete.
# Generation Finished In : 1299426.8338680267, ms

# %%
## Create Fine Tuning Dataset
fine_tuning_dataset = create_table_dataset(llm_output)
print("Dataset is Generated as a CSV File. Please rename it before running this notebook again")
# Out:
# ['"Verify the functionality of the Button Element \'SEARCH\'"', '"The user is on a webpage with a SEARCH button visible"', '"\'1. User navigates to a webpage where SEARCH button exists \'\' \'2. Click on the SEARCH button\'\' \'3. Verify if the size attribute of the button remains as {\'height\': 36.0, \'width\': 42.0}\'\' \'4. Verify if the background color remains as rgb(46, 108, 0)"', '"The Button Element \'SEARCH\' should not change its size and background color when clicked."']
# ['"Verify the functionality of the Button Element Without Name"', '"The user is on a webpage with a styled button element"', '"\'1. User navigates to the webpage \'https://example.com/\' \'\' \'2. Verify if the button element has size attributes \'height\': 38.80000305175781 and \'width\': 40.0 \'3. Click on the Button Element Without Name\'\' \'4. Verify if the background color of the button changes"', '"Upon clicking, the background color should change."']
# ['"Verify the functionality of the Link Element \'Inquire\'"', '"The user is on the webpage \'https://bicol-u.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://bicol-u.edu.ph/\'\' \'2. Click on Link Element \'Inquire\'\' \'3. Verify if the link url changes to \'https://cisph.openapply.com/roi\' \'4. Verify if the webpage opens in a new tab/window\'"', '"Webpage \'https://cisph.openapply.com/roi/\' should open in a new tab/window."']
# ['"Verify the functionality of the Link Element \'ManageBac\'"', '"The user is on the webpage \'https://bicol-u.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://bicol-u.edu.ph/\'\' \'2. Click on Link Element \'ManageBac\' \'3. Verify if the link url changes to \'https://cisph.managebac.com/\' \'4. Verify if the webpage opens in a new tab/window\'"', '"Webpage \'https://cisph.managebac.com/\' should open in a new tab/window."']
# ['"Verify the functionality of the Link Element \'Quick Links\'"', '"The user is on the webpage \'https://cis.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://cis.edu.ph/\'\' \'2. Click on Link Element \'Quick Links\'\' \'3. Verify if the link url changes to \'https://cis.edu.ph/#\' \'4. Verify if a dropdown below \'Quick Links\' is visible\'"', '"A dropdown should show below \'Quick Links\', but the webpage does not change."']
# ['"Verify the functionality of the Link Element Without Name"', '"The user is on the webpage \'https://cis.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://cis.edu.ph/\'\' \'2. Click on Link Element Without Name\' \'3. Verify if the link url changes to \'https://cis.edu.ph/\' \'4. Verify if a rel attribute with value \'home\' is present\'"', '"The rel attribute with value \'home\' should be present, but no change in webpage."']
# ['"Verify the functionality of the Link Element \'Cebu International School\'"', '"The user is on the webpage \'https://cis.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://cis.edu.ph/\' \'\' \'2. Click on Link Element \'Cebu International School\'\' \'3. Verify if the link url changes to \'https://cis.edu.ph/\' \'4. Verify if the rel attribute value is displayed as \'home\'"', '"Webpage\'s URL remains unchanged, and the rel attribute displays correctly."']
# ['"Verify the functionality of the Link Element \'HOME\'"', '"The user is on the webpage \'https://cis.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://cis.edu.ph/\'\' \'2. Click on Link Element \'HOME\'\' \'3. Verify if the webpage opens in a new tab/window.\'"', '"Webpage \'https://cis.edu.ph/\' should open in a new tab/window."']
# ['"Verify the functionality of the Link Element \'EXPLORE\'"', '"The user is on the webpage \'https://cis.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://cis.edu.ph/\'\' \'2. Click on Link Element \'EXPLORE\'\' \'3. Verify if the link url changes to \'https://cis.edu.ph/#\' \'4. Verify if a dropdown below \'EXPLORE\' is visible\'"', '"A dropdown should show below \'EXPLORE\', but the webpage does not change"']
# ['"Verify the functionality of the Link Element \'LEARN\'"', '"The user is on the webpage \'https://cis.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://cis.edu.ph/\'\' \'2. Click on Link Element \'LEARN\'\' \'3. Verify if the link url changes to \'https://cis.edu.ph/#\' \'4. Verify if a new tab/window opens\'"', '"Webpage should open in a new tab/window with URL \'https://cis.edu.ph/\'"']
# ['"Verify the functionality of the Link Element \'DISCOVER\'"', '"The user is on the webpage \'https://cis.edu.ph/ \'"', '"\'1. User navigates to the webpage \'https://cis.edu.ph/\' \'2. Click on Link Element \'DISCOVER\' \'3. Verify if the link url changes to \'https://cis.edu.ph/#\'\' "', '"A dropdown should not show below \'DISCOVER\', but the webpage does not change"']
# ['"Verify the functionality of the Link Element \'JOIN\'"', '"The user is on the webpage \'https://cis.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://cis.edu.ph/\' \'2. Click on Link Element \'JOIN\'\' \'3. Verify if the link url changes to \'https://cis.edu.ph/#\' \'4. Verify if a dropdown below \'JOIN\' is visible\'"', '"A dropdown should show below \'JOIN\', but the webpage does not change"']
# ['"Verify the functionality of the Link Element \'COMMUNITY\'"', '"The user is on the webpage \'https://cis.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://cis.edu.ph/\'\' \'2. Click on Link Element \'COMMUNITY\'\' \'3. Verify if the link url changes to \'https://cis.edu.ph/#\' \'4. Verify if a dropdown below \'COMMUNITY\' is visible\'"', '"A dropdown should show below \'COMMUNITY\', but the webpage does not change"']
# ['"Verify the functionality of the unnamed Link Element"', '"The user is on the webpage \'https://www.youtube.com/\'"', '"\'1. User navigates to the webpage \'https://www.youtube.com/\'\' \'2. Click on Link Element Without Name\'\' \'3. Verify if the link url changes to \'https://www.youtube.com/watch?v=t1AxChLTVrg\' \'4. Verify if the webpage opens in a new tab/window\'"', '"Webpage \'https://www.youtube.com/watch?v=t1AxChLTVrg\' should open in a new tab/window."']
# ['"Verify the functionality of the Link Element \'Previous\'"', '"The user is on the webpage \'https://cis.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://cis.edu.ph/\'\' \'2. Click on Link Element \'Previous\'\' \'3. Verify if the link url changes to \'https://cis.edu.ph/#\' \'4. Verify if a previous page dropdown is visible"', '"A previous page dropdown should show, but the webpage does not change"']
# ['"Verify the functionality of the Link Element \'Next\'"', '"The user is on the webpage \'https://cis.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://cis.edu.ph/\' \'\' \'2. Click on Link Element \'Next\'\' \'3. Verify if the link url changes to \'https://cis.edu.ph/#\' \'4. Verify if the webpage does not refresh or change\'"', '"The URL of the link should change to \'https://cis.edu.ph/#\', but the webpage remains the same."']
# ['"Verify the functionality of the Link Element \'Welcome Message\'"', '"The user is on the webpage \'https://cis.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://cis.edu.ph/\' \'\' \'2. Click on Link Element \'Welcome Message\'\' \'3. Verify if the link url changes to \'https://cis.edu.ph/explore/welcome/\' \'4. Verify if a new tab/window opens with the link url\'"', '"Webpage \'https://cis.edu.ph/explore/welcome/\' should open in a new tab/window."']
# ['"Verify the functionality of the Link Element \'Guiding Statements\'"', '"The user is on the webpage \'https://cis.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://cis.edu.ph/\' \'\' \'2. Click on Link Element \'Guiding Statements\'\' \'3. Verify if the link url changes to \'https://cis.edu.ph/explore/guiding-statements/\'"', '"Webpage \'https://cis.edu.ph/explore/guiding-statements/\' should open in a new tab/window."']
# ['"Verify the functionality of the Link Element \'School Calendar\'"', '"The user is on the webpage \'https://cis.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://cis.edu.ph/\'\' \'2. Click on Link Element \'School Calendar\'\' \'3. Verify if the link url changes to \'https://cis.edu.ph/explore/school-calendar/\'"', '"Webpage \'https://cis.edu.ph/explore/school-calendar/\' should open in a new tab/window."']
# ['"Verify the functionality of the Link Element \'History\'"', '"The user is on the webpage \'https://cis.edu.ph/ \'"', '"\'1. User navigates to the webpage \'https://cis.edu.ph/\'\' \'2. Click on Link Element \'History\'\' \'3. Verify if the link url changes to \'https://cis.edu.ph/explore/history/\' \'4. Verify if a dropdown or other elements are visible below \'History\'\'"', '"The link url should change to \'https://cis.edu.ph/explore/history/ \'"']
# ['"Verify the functionality of the Link Element \'Governance\'"', '"The user is on the webpage \'https://bicol-u.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://bicol-u.edu.ph/\'\' \'2. Click on Link Element \'Governance\'\' \'3. Verify if the link url changes to https://cis.edu.ph/explore/board-of-trustees/"', '"The link URL should change to https://cis.edu.ph/explore/board-of-trustees/, but the webpage does not change."']
# ['"Verify the functionality of the Link Element \'Campus Facilities\'"', '"The user is on the webpage \'https://bicol-u.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://bicol-u.edu.ph/\'\' \'2. Click on Link Element \'Campus Facilities\'\' \'3. Verify if the link url changes to \'https://cis.edu.ph/explore/campus-facilities/\'"', '"Webpage \'https://cis.edu.ph/explore/campus-facilities/\' should open in a new tab/window."']
# ['"Verify the functionality of the Link Element \'Early Years\'"', '"The user is on the webpage \'https://cis.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://cis.edu.ph/\' \'\' \'2. Click on Link Element \'Early Years\'\' \'3. Verify if the link url changes to \'https://cis.edu.ph/learn/early-years/\'"', '"Webpage \'https://cis.edu.ph/learn/early-years/\' should open in a new tab/window."']
# ['"Verify the functionality of the Link Element \'Primary Years\'"', '"The user is on the webpage \'https://cis.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://cis.edu.ph/\' \'\' \'2. Click on Link Element \'Primary Years\'\' \'3. Verify if the link url changes to \'https://cis.edu.ph/learn/primary-years/\' \'4. Verify if the webpage opens in a new tab/window\'"', '"Webpage \'https://cis.edu.ph/learn/primary-years/\' should open in a new tab/window."']
# ['"Verify the functionality of the Link Element \'Middle Years\'"', '"The user is on the webpage \'https://bicol-u.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://bicol-u.edu.ph/\'\' \'2. Click on Link Element \'Middle Years\'\' \'3. Verify if the link url changes to \'https://cis.edu.ph/learn/middle-years/\'"', '"Webpage \'https://cis.edu.ph/learn/middle-years/\' should open in a new tab/window."']
# ['"Verify the functionality of the Link Element \'Diploma Programme\'"', '"The user is on the webpage \'https://cis.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://cis.edu.ph/\' \'\' \'2. Click on Link Element \'Diploma Programme\'\' \'3. Verify if the link url changes to \'https://cis.edu.ph/learn/diploma-programme/\' "', '"Webpage \'https://cis.edu.ph/learn/diploma-programme/\' should open in a new tab/window."']
# ['"Verify the functionality of the Link Element \'21st Century Learning\'"', '"The user is on the webpage \'https://cis.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://cis.edu.ph/\' \'\' \'2. Click on Link Element \'21st Century Learning\'\' \'3. Verify if the link url changes to \'https://cis.edu.ph/learn/21st-century-learning/\' \'4. Verify if a new tab/window opens with the correct webpage"', '"Webpage \'https://cis.edu.ph/learn/21st-century-learning/\' should open in a new tab/window."']
# ['"Verify the functionality of the Link Element \'Student Support\'"', '"The user is on the webpage \'https://cis.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://cis.edu.ph/\' \'\' \'2. Click on Link Element \'Student Support\'\' \'3. Verify if the link url changes to \'https://cis.edu.php/student-support/ \'\' \'4. Verify if the webpage opens in a new tab/window\'"', '"Webpage \'https://cis.edu.ph/student-support/\' should open in a new tab/window."']
# ['"Verify the functionality of the Link Element \'Arts\'"', '"The user is on the webpage \'https://cis.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://cis.edu.ph/\' \'\' \'2. Click on Link Element \'Arts\'\' \'3. Verify if the link url changes to \'https://cis.edu.ph/discover/arts/\' \'4. Verify if the webpage opens in a new tab/window\'"', '"Webpage \'https://cis.edu.ph/discover/arts/\' should open in a new tab/window."']
# ['"Verify the functionality of the Link Element \'Sports & Athletics\'"', '"The user is on the webpage "https://cis.edu.ph/" with url https://cis.edu.ph/discover/sports-athletics/"', '"\'1. User navigates to the webpage \'https://cis.edu.ph/\'\' \'2. Click on Link Element \'Sports & Athletics\' "', '"Webpage https://cis.edu.php/discover/sports-athletics/\' should open in a new tab/window."']
# ['"Verify the functionality of the Link Element \'Leadership\'"', '"The user is on the webpage \'https://cis.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://cis.edu.ph/\' \'\' \'2. Click on Link Element \'Leadership\'\' \'3. Verify if the link url changes to \'https://cis.edu.ph/discover/student-leadership/\' \'4. Verify if the webpage opens in a new tab/window\'"', '"Webpage \'https://cis.edu.ph/discover/student-leadership/\' should open in a new tab/window."']
# ['"Verify the functionality of the Link Element \'Extra Curricular\'"', '"The user is on the webpage \'https://cis.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://cis.edu.ph/\'\' \'2. Click on Link Element \'Extra Curricular\'\' \'3. Verify if the link url changes to \'https://cis.edu.ph/discover/asa/\'"', '"Webpage \'https://cis.edu.ph/discover/asa/\' should open in a new tab/window."']
# ['"Verify the functionality of the Link Element \'Admissions\'"', '"The user is on the webpage \'https://cis.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://cis.edu.ph/\' \'\' \'2. Click on Link Element \'Admissions\'\' \'3. Verify if the link url changes to \'https://cis.edu.ph/join/admissions/\'"', '"Webpage \'https://cis.edu.ph/join/admissions/\' should open in a new tab/window."']
# ['"Verify the functionality of the Link Element \'Inquire\'"', '"The user is on the webpage "https://bicol-u.edu.ph/"\'"', '"\'1. User navigates to the webpage "https://bicol-u.edu.ph/\'\' \'2. Click on Link Element \'Inquire\'\' \'3. Verify if the link url changes to https://cisph.openapply.com/\'"', '"Webpage \'https://cisph.openapply.com/\' should open in a new tab/window."']
# ['"Verify the functionality of the Link Element \'Admissions FAQ\'"', '"The user is on the webpage \'https://cis.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://cis.edu.ph/\' \'\' \'2. Click on Link Element \'Admissions FAQ\'\' \'3. Verify if the link url changes to \'https://cis.edu.ph/join/admissions/faq/\'"', '"Webpage \'https://cis.edu.ph/join/admissions/faq/\' should open in a new tab/window."']
# ['"Verify the functionality of the Link Element \'Student Residence\'"', '"The user is on the webpage \'https://cis.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://cis.edu.ph/\' \'\' \'2. Click on Link Element \'Student Residence\'\' \'3. Verify if the link url changes to \'https://cis.edu.ph/join/student-residence/\' \'4. Verify if the webpage opens in a new tab/window\'"', '"Webpage \'https://cis.edu.ph/join/student-residence/\' should open in a new tab/window."']
# ['"Verify the functionality of the Link Element \'Scholarships\'"', '"The user is on the webpage \'https://cis.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://cis.edu.ph/\' \'\' \'2. Click on Link Element \'Scholarships\'\' \'3. Verify if the link url changes to \'https://cis.edu.ph/join/scholarships/\'\'\' ', ' "The link url should change to \'https://cis.edu.php/join/scholarships/.\'"']
# ['"Verify the functionality of the Link Element \'Careers\'"', '"The user is on the webpage \'https://cis.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://cis.edu.ph/\' \'\' \'2. Click on Link Element \'Careers\'\' \'3. Verify if the link url changes to \'https://cis.edu.ph/join/careers/\' \'4. Verify if a new tab/window opens with the correct URL\'"', '"A new tab/window should open with the URL \'https://cis.edu.ph/join/careers/\'"']
# ['"Verify the functionality of the Link Element \'Life in Cebu\'"', '"The user is on the webpage \'https://cis.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://cis.edu.ph/\' \'\' \'2. Click on Link Element \'Life in Cebu\'\' \'3. Verify if the link url changes to \'https://cis.edu.ph/join/life-in-cebu/\' \'4. Verify if the webpage opens in a new tab/window\'"', '"Webpage \'https://cis.edu.ph/join/life-in-cebu/\' should open in a new tab/window."']
# ['"Verify the functionality of the Link Element \'Bulletin\'"', '"The user is on the webpage \'https://cis.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://cis.edu.ph/\' \'\' \'2. Click on Link Element \'Bulletin\'\' \'3. Verify if the link url changes to \'https://cis.edu.ph/community/bulletin/\'"', '"Webpage \'https://cis.edu.ph/community/bulletin/\' should open in a new tab/window."']
# ['"Verify the functionality of the Link Element \'Newsflash\'"', '"The user is on the webpage \'https://cis.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://cis.edu.ph/\' \'\' \'2. Click on Link Element \'Newsflash\'\' \'3. Verify if the link url changes to \'https://cis.edu.ph/community/newsflash/\'\' \'4. Verify if the webpage opens in a new tab/window\'"', '"Webpage \'https://cis.edu.ph/community/newsflash/\' should open in a new tab/window."']
# ['"Verify the functionality of the Link Element \'Alumni Network\'"', '"The user is on the webpage \'https://cis.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://cis.edu.ph/\' \'\' \'2. Click on Link Element \'Alumni Network\'\' \'3. Verify if the link url changes to \'https://cis.edu.ph/community/alumni-network/\' \'4. Verify if the link opens in a new tab/window"', '"Webpage \'https://cis.edu.ph/community/alumni-network/\' should open in a new tab/window."']
# ['"Verify the functionality of the Link Element \'PTA\'"', '"The user is on the webpage \'https://cis.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://cis.edu.ph/\'\' \'2. Click on Link Element \'PTA\'\' \'3. Verify if the link url changes to \'https://cis.edu.ph/community/pta/\'"', '"Webpage \'https://cis.edu.ph/community/pta/\' should open in a new tab/window."']
# ['"Verify the functionality of the Link Element \'Privacy Policy\'"', '"The user is on the webpage \'https://cis.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://cis.edu.ph/\' \'\' \'2. Click on Link Element \'Privacy Policy\'\' \'3. Verify if the link url changes to \'https://cis.edu.ph/privacy-policy/\' \'4. Verify if the webpage opens in a new tab/window\'"', '"Webpage \'https://cis.edu.ph/privacy-policy/\' should open in a new tab/window."']
# ['"Verify the functionality of the Link Element \'Google Analytics\'"', '"The user is on the webpage \'https://www.example.com/\'"', '"\'1. User navigates to the webpage \'https://www.example.com/\'\' \'2. Click on Link Element \'Google Analytics\'\' \'3. Verify if the link url changes to \'https://policies.google.com/terms\' \'4. Verify if a new tab/window opens with the Google Analytics terms page\'"', '"A new tab/window should open with the Google Analytics terms page."']
# ['"Verify the functionality of the Link Element \'Google privacy practices\'"', '"The user is on the webpage \'https://www.example.com/\'"', '"\'1. User navigates to the webpage \'https://www.example.com/\' \'\' \'2. Click on Link Element \'Google privacy practices\'\' \'3. Verify if the link url changes to \'https://policies.google.com/privacy\' \'4. Verify if the webpage opens in a new tab/window\'"', '"Webpage \'https://policies.google.com/privacy/\' should open in a new tab/window."']
# ['"Verify the functionality of the Link Element \'privacy notice\'"', '"The user is on the webpage \'https://cis.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://cis.edu.ph/\' \'2. Click on Link Element \'privacy notice\'\' \'3. Verify if the link url changes to \'https://cis.edu.ph/privacy-policy/\' \'4. Verify if the webpage opens in a new tab/window\'"', '"Webpage \'https://cis.edu.ph/privacy-policy/\' should open in a new tab/window."']
# ['"Verify the functionality of the Link Element \'Cookie settings\'"', '"The user is on the webpage with a link to click, but no actual link url is provided."', '"\'1. User navigates to a test webpage.\'\' \'2. Check if Link Element \'Cookie settings\' exists on the webpage\'\' \'3. Click on Link Element \'Cookie settings\'\'"', '"No webpage should open since there\'s no actual URL linked to it."']
# ['"Verify the functionality of the Link Element \'ACCEPT\'"', '"The user is on the webpage with no link associated."', '"\'1. User clicks on Link Element \'ACCEPT\'\' "2. Verify if a message or alert appears due to missing link url"', '"An error message should appear indicating that there\'s no link to follow."']
# ['"Verify the functionality of the Heading Element \'ABOUT CIS\'"', '"The user is on any webpage."', '"\'1. User navigates to any webpage.\' \'2. Verify if the heading \'ABOUT CIS\' is visible.\'"', '"Heading \'ABOUT CIS\' should be visible and display its text content."']
# ['"Verify the functionality of the Heading Element \'ACADEMIC PROGRAM\'"', '"The user is on the webpage with URL"', '"\'1. User navigates to the webpage with URL " "2. Verify if the heading \'ACADEMIC PROGRAM\' is visible"', '"Heading \'ACADEMIC PROGRAM\' should be visible on the webpage."']
# ['"Verify the functionality of the Heading Element \'STUDENT LIFE\'"', '"The user is on the webpage \'https://bicol-u.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://bicol-u.edu.ph/\'\' \'2. Verify if the heading element \'STUDENT LIFE\' is visible and has correct formatting"', '"Heading Element \'STUDENT LIFE\' should be visible and correctly formatted on the webpage."']
# ['"Verify the functionality of the Heading Element \'JOIN\'"', '\n"The user is on the webpage with a functional header"', ' \n"\'1. User navigates to a webpage that uses HTML h2\' \'2. Verify if the heading \'JOIN\' is displayed on the page"', ' \n"A heading \'JOIN\' should be visible and properly formatted."']
# ['"Verify the functionality of the Heading Element \'COMMUNITY\'"', '"The user is on the webpage and has loaded the content."', '"\'1. User navigates to the page where the heading \'COMMUNITY\' is displayed \'2. Verify if the heading text is correct."', '"The heading text should be \'COMMUNITY\'."']
# ['"Verify the functionality of the Heading Element \'100%\'"', '"The user is on a webpage with layout settings that allow a heading to have a width of 100%"', '"\'1. User navigates to a webpage with a layout setting allowing headings to span full-width\'\' \'2. Verify if the Heading Element \'100%\' has a width of 100%\'\' \'3. Check if the heading is properly formatted and visible on the page"', '"Heading Element \'100%\' should have a width of 100%."']
# ['"Verify the functionality of the Heading Element \'20+\'"', '"The user is on the webpage with heading \'20+\'"', '"\'1. User navigates to the webpage \'https://www.example.com/\' or similar\'\'', '"No expected result as it\'s a heading element."']
# ['"Verify the functionality of the Heading Element \'7:1\'"', '"The user is on the webpage \'https://example.com/current-page\'"', '"\'1. User navigates to the webpage \'https://example.com/current-page\'\' \'2. Verify if the heading element \'7:1\' is visible and correctly displayed as an h6 tag."', '"Heading Element \'7:1\' should be visible and correctly displayed as an h6 tag on the webpage."']
# ['"Verify the functionality of the Heading Element \'100\'"', '"The user is on the webpage where this heading exists."', '"\'1. User navigates to the webpage containing the heading.\' \'2. Verify if the heading \'100\' is visible and has correct font size.\'"', '"Heading \'100\' should be visible with correct font size."']
# ['"Verify the functionality of the Paragraph Element \'Cebu International School\'"', '"The user is on the webpage \'https://bicol-u.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://bicol-u.edu.ph/\'\' \'2. Click on Page Source (Inspect) \'3. Verify if the paragraph text \'Cebu International School\' exists\'"', '"Paragraph text \'Cebu International School\' should exist."']
# ['"Verify the functionality of the Paragraph Element: \'PASS RATE FOR IBDP\'"', '"The user is on the webpage \'https://bicol-u.edu.ph/\'"', '"\'1. User navigates to the webpage \'https://bicol-u.edu.ph/\'\' \'2. Verify if the paragraph text \'PASS RATE FOR IBDP\' is visible on the webpage"', '"Paragraph text \'PASS RATE FOR IBDP\' should be visible and readable."']
# ['"Verify the functionality of the Paragraph Element \'NATIONALITIES REPRESENTED\'"', '"The user is on the webpage displaying text \'NATIONALITIES REPRESENTED\'."', '"\'1. User navigates to a webpage displaying text \'NATIONALITIES REPRESENTED\'. \'2. Verify if the paragraph is displayed as expected, with no broken links or images.\'"', '"Paragraph Element \'NATIONALITIES REPRESENTED\' should be displayed without any issues."']
# ['"Verify the usability of the Paragraph Element \'AVERAGE STUDENT-TEACHER RATIO\'"', '"The user is on the webpage containing the paragraph element"', '"\'1. User navigates to a webpage with the correct text displayed\' \'2. Verify if the paragraph \'AVERAGE STUDENT-TEACHER RATIO\' is visible and readable\' \'3. Check for any broken links or buttons associated with the paragraph\'"', '"The paragraph \'AVERAGE STUDENT-TEACHER RATIO\' should be visible, readable and not contain any broken links."']
# ['"Verify the functionality of the Paragraph Element \'YEARS OF EXPERIENCE\'"', '"The user is on the webpage and the paragraph text is visible."', '"\'1. User navigates to the webpage \'\' \'2. Verify if the paragraph with text \'YEARS OF EXPERIENCE\' is visible.\'"', '"Paragraph text \'YEARS OF EXPERIENCE\' should be displayed on the webpage."']
# ['"Verify the functionality of the Paragraph Element"', '"The user is on the webpage with content \' \'\'"', '"\'1. User navigates to the webpage with content \'\'\' \'2. Verify if the paragraph text remains unchanged\'"', '"Paragraph text should remain unchanged."']
# ['"Verify the functionality of the Paragraph Element"', '"The user is on a webpage with editable text fields"', '"\'1. User navigates to a webpage with editable text fields\' \'2. Click inside the text field\'"', '"Text cursor should be visible and user can input text."']
# ['Since there are no properties or link attached to the given "Paragraph Element", I will assume it\'s not a functional test case for usability. However, here\'s a default output:\n\n"Verify the functionality of the Paragraph Element"', '"The user is on any webpage"', '"\'1. User navigates to an arbitrary webpage \'\' \'2. Verify if the paragraph element exists and is visible\'"', '"Paragraph element should exist and be visible."']
# ['"Verify the usability of the Paragraph Element"', '"The user is on a webpage with a visible paragraph section"', '"\'1. User navigates to a webpage \'2. The paragraph text should be readable and free from any formatting errors\'3. Verify if the paragraph content is scrollable\'"', '"Paragraph content should be readable, not scrollable."']
# ['"Verify the usability of the Paragraph Element"', '"The user is on the webpage where the paragraph element resides"', '"\'1. User navigates to the webpage containing the paragraph element\'\' \'2. Verify if the text within the paragraph element is visible and not truncated\'"', '"Text within the paragraph element should be visible and not truncated."']
# ['"Verify the readability of the Privacy Policy text"', '"The user is on the webpage containing the paragraph text"', '"\'1. User navigates to the webpage containing the paragraph text \'\' \'2. Check if the displayed text matches \'Privacy Policy\n\xa0 \xa0 \xa0 \xa0 \xa0 \xa0\'Privacy Policy\n\xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0\' \'3. Verify if the copyright year is accurate and visible"', '"The Privacy Policy text should be readable, display accurately, and show a valid copyright year."']
# ['"Verify the functionality of the Input Field Element \'s\'"', '"The user is on a webpage where input field \'s\' is visible and editable"', '"\'1. User navigates to a webpage where input field \'s\' is visible and editable \'\' \'2. Click on input field \'s\'\' \'3. Enter \'test\' value into the search bar\' \'4. Submit or click outside the input field to verify if autocomplete functionality works\'"', '"Input Field \'s\' should suggest possible searches when user enters a keyword."']
# Dataset is Generated as a CSV File. Please rename it before running this notebook again

# %%
fine_tuning_dataset.to_csv(f"test.csv", sep='\t', encoding='utf-8', index=False, header=True)

# %% [markdown]
# #### Prototype Code

# %%
# # Imports

# # Langchain and Ollama
# import langchain
# from langchain_ollama.llms import OllamaLLM
# from langchain_core.prompts import ChatPromptTemplate

# # BeautifulSoup and Requests
# from bs4 import BeautifulSoup
# import requests

# # Math
# from math import ceil,floor
# import csv

# # Selenium
# import selenium
# from selenium import webdriver
# from selenium.webdriver.common.by import By
# from time import sleep

# # Pandas
# import pandas as pd

# %%
# # Table File Generator

# def dataframe_init(in_data, out_data, text_data):
#     # initialize data of lists.
#     data = {"output" : out_data, 
#            "input" : in_data,
#            "instruction" : text_data}

#     # Create DataFrame
#     df = pd.DataFrame(dict([(key, pd.Series(value)) for key, value in data.items()]))
#     # df = pd.DataFrame(data)
#     return df

# %%
# # CSV Generator

# def csv_from_test_case_batches(filename, input_column, output_column, text_column):
#     cols = dataframe_init(input_column, output_column, text_column)
#     cols.to_csv(f"{filename}.csv", sep='\t', encoding='utf-8', index=False, header=True)

# %%
# # Scraper

# # GET URL FUNCTION
# def get_url():
#     return input("Enter Website URL: ")

# def data_scrape(url):
#     # Set up Selenium with a WebDriver, e.g., ChromeDriver
#     driver = webdriver.Firefox()
    
#     # Open the website
#     driver.get(url)
    
#     # Find all visible buttons
#     buttons = driver.find_elements(By.CSS_SELECTOR, "button")
#     visible_buttons = []
#     for button in buttons:
#         if button.is_displayed():
#             store = f"Button Element: {button.text} with URL : {button.get_attribute('href')}"
#             visible_buttons.append(store)
            
#     # Find all visible links
#     links = driver.find_elements(By.TAG_NAME,"a")
#     visible_links = []
#     for link in links:
#         if link.is_displayed():
#             store = f"Link Element: {link.text} with URL : {link.get_attribute('href')}"
#             visible_links.append(store)
            
#     # Find all visible forms (text inputs)
#     visible_text_inputs = []
#     # Scrape input fields
#     input_fields = driver.find_elements(By.TAG_NAME,"input")
#     for input_field in input_fields:
#         if input_field.is_displayed():
#             store = f"Input Field Name: {input_field.get_attribute("name")} Input field type: {input_field.get_attribute("type")}"
#             visible_text_inputs.append(store)
    
#     # Find all visible text
#     visible_text = []
#     # Scrape headings
#     for level in range(1, 7):  # HTML has 6 levels of headings (h1 to h6)
#         headings = driver.find_elements(By.TAG_NAME,f"h{level}")
#         for heading in headings:
#             if heading.is_displayed():
#                 store = f"Heading (h{level}): {heading.text}"
#                 visible_text.append(store)
#     # Scrape text content
#     paragraphs = driver.find_elements(By.TAG_NAME,"p")
#     for paragraph in paragraphs:
#         if paragraph.is_displayed():
#             store = f"Paragraph Text: {paragraph.text}"
#             visible_text.append(store)
            
#     # Find all visible navigation menus
#     visible_nav_menus = []
#     # Scrape navigation menus
#     navigation_menus = driver.find_elements(By.TAG_NAME,"nav")
#     for nav in navigation_menus:
#         if nav.is_displayed():
#             store = f"Navigation Menu: {nav.text}"
#             visible_nav_menus.append(store)
            
#     # Close the browser
#     driver.quit()

#     # Return Data
#     data = []
    
#     # Data append
#     data.append(visible_buttons)
#     data.append(visible_links)
#     data.append(visible_text_inputs)
#     data.append(visible_text)
#     data.append(visible_nav_menus)

#     return data

# %%
# # Prompt Generator + LLM

# # CONTEXT
# template = """
# You are a quality assurance expert that generates functional test cases for websites. You take in a UI element and you generate a functional test case.

# Here is the UI element (some elements have a link attached to them): {question}
# ONLY output in the following format: 
# "Objective"~"Preconditions"~"Test Steps"~"Expected Result"

# DO NOT output any other text. DO NOT output 'Here are the test cases...', your output should be like the example output below.

# Example Input:
# Link Element: Home with URL : https://bicol-u.edu.ph/
# Link Element: Academics with URL : https://bicol-u.edu.ph/#
# ...

# Example Output:
# "Verify the functionality of the Link Element 'Home'"~"The user is on the webpage 'https://bicol-u.edu.ph/'"~"'1. User navigates to the webpage \'https://bicol-u.edu.ph/\'' '2. Click on Link Element \'Home\'' '3. Verify if the webpage opens in a new tab/window.'"~"Webpage 'https://bicol-u.edu.ph/' should open in a new tab/window."
# "Verify the functionality of the Link Element 'Academics'"~"The user is on the webpage 'https://bicol-u.edu.ph/'"~"'1. User navigates to the webpage \'https://bicol-u.edu.ph/\'' '2. Click on Link Element \'Academics\'' '3. Verify if the link url changes to \'https://bicol-u.edu.ph/#\'' '4. Verify if a dropdown below \'Academics\' is visible'"~"A dropdown should show below 'Academics', but the webpage does not change"
# ...

# """

# # Load Model Chain
# def load_model_chain(template : str =  template, model_str : str = "llama3.1"):
#     # Prompt
#     prompt = ChatPromptTemplate.from_template(template)
#     # Model
#     model = OllamaLLM(model=model_str)
#     # Chain
#     chain = prompt | model
#     return chain

# # Create Test Case Data
# def create_test_cases(data, chain, model_str : str = "llama3.1" , template : str = template, batch_size : int = 10):
    
#     return_data = []
    
#     for sub_data in data:
#         element_test_cases = []
#         i = 0
#         j = 0
#         print(f"Batch Number: {ceil(len(sub_data)/batch_size)}")
#         while (j<ceil(len(sub_data)/batch_size)):
#             print(f"[{j}] Batch {str(len(sub_data[i:i+batch_size]))}")
#             appending = []
#             for dat in sub_data[i:i+batch_size]:
#                 appending.append(chain.invoke({"question": str(dat)}))
#             element_test_cases.append(appending)
#             i+=batch_size
#             j+=1
#             prompt = ChatPromptTemplate.from_template(template)
#             model = OllamaLLM(model=model_str)
#             chain = prompt | model
#         return_data.append(element_test_cases)
#     return return_data

# %%
# # Main Program

# # FILENAME
# filename = "sample_name"
# # URL
# url = get_url()
# # DATA
# data = data_scrape(url) # Returns Link Data Only For Now

# # Prepare data to be plcaed in the Input Column
# input_data = []
# for item_set in data:
#     for item in item_set:
#         input_data.append(item)

# # CHAIN
# chain = load_model_chain()
# # GENERATE TEST CASES
# test_cases = create_test_cases(data, chain)

# # Prepare data to be plcaed in the Output Column [Split]
# split_sets = []
# for test_case_set in test_cases:
#     for test_case in test_case_set:
#         for test in test_case:
#             split_sets.append(test.split('~'))
# # Prepare data to be plcaed in the Output Column [Actual Column]
# output_data = []
# for sp in split_sets:
#     output_data.append(sp)
    
# # Fine-Tuning Template
# text_data = []
# i = 0
# while (i < len(input_data)):
#     template = f"####Question:\n Generate test case for the following UI element: {input_data[i]}"
#     text_data.append(template)
#     i+=1
    
# # CSV OUTPUT
# csv_from_test_case_batches(filename, input_data, output_data, text_data)
